# %%
# standard packages
import os
from collections import defaultdict
from collections import Counter
from datetime import datetime
from datetime import date
import subprocess
from shlex import quote
import shlex
# non-standard packages, get these via conda
from Bio import SeqIO
try:
    import pandas as pd
    import plotly.express as px
    import plotly.io as pio
    pio.renderers.default = 'notebook'
    plotting=True
except ModuleNotFoundError:
    print(f'did not find plotting packages, no stats will be run')
    plotting=False

# %% [markdown]
# #  Pépinière
# This notebook contains a bunch of scripts that can process and clean up data from GISAID/BVBRC. It takes any number of fasta files and combines them into one final file. It requires metadata with time, species and continent of isolation

# %% [markdown]
# Specify the fasta files and metadata files here and specify which website they were downloaded from. The sequences from the different files will be concatenated into a single file and duplicates will be removed during the process.
#
# GISAID files should be dowloaded with fasta header format: Type|  DNA INSDC   | Isolate name   | DNA Accession no., YYYY-MM-DD format and both space replacement/removal checked.<p>
# BVBRC files should be downloaded in standard format and will be reformatted later

# %%
# tuple of files containing the sequences
# (<path>, <GISAID/BVBRC>)
seq_files=(('/Users/threecats/Data/FluSeq/trees/h5_all/raw/gisaid_all-h5-170101.fasta', 'GISAID'),
           ('/Users/threecats/Data/FluSeq/trees/h5_all/raw/gisaid_all-h5-170101-230209.fasta', 'GISAID'),
           ('/Users/threecats/Data/FluSeq/trees/h5_all/raw/BVBRC_all-h5-230214-1.fasta', 'BVBRC'),
           ('/Users/threecats/Data/FluSeq/trees/h5_all/raw/BVBRC_all-h5-230214-2.fasta', 'BVBRC'))

# tuple of files containing metadata
# (<path>, <GISAID/BVBRC>)
metadata_files=(('/Users/threecats/Data/FluSeq/trees/h5_all/raw/gisaid_mdata_all-h5-170101.tsv', 'GISAID'),
                ('/Users/threecats/Data/FluSeq/trees/h5_all/raw/gisaid_mdata_all-h5-170101-230214.tsv', 'GISAID'),
                ('/Users/threecats/Data/FluSeq/trees/h5_all/raw/BVBRC_mdata_all-h5-230214-1.txt', 'BVBRC'),
                ('/Users/threecats/Data/FluSeq/trees/h5_all/raw/BVBRC_mdata_all-h5-230214-2.txt', 'BVBRC'))

# path the species list if used
species_list='/Users/threecats/Data/git/pepiniere/species_list_sorted.txt'

# string pointing at the directory where you want the data
output_dir='/Users/threecats/Data/FluSeq/trees/h5_all'

# name of final dataset
name='allH5'

# %% [markdown]
# # 0. Set up
# Import packages, set up functions and variables

# %%
## TOGGLES
# these two steps can be very time consuming depending on the size of the dataset
# you may also want to use other software to analyze your dataset, though MAFFT 
# and fasttree are probably fine for a first look at the data
# !!! mafft, fasttree and treetime need to be installed in your python environment
# you can get them all via conda.

# should we align the data with MAFFT?
toggle_align=True
# how many threads to use for alignment? This can speed it up significantly, 
# but should note exceed teh number of cores your computer has
threads_align=8
# should we make a fasttree?
toggle_tree=True
# should we make a treetime?
toggle_treetime=True

## REPORTING PARAMETERS
# should we output report files?
report_files = True
# identical sequences isolated *more* than these many years apart will be reported on
year_gap_threshold = 1
##

## DATASET CURATION OPTIONS
# should we try to correct common metadata errors?
corr_mdata = True
# should we throw out all files without minimal metadata (ie date)
purge_nomdata = True
# should we only keep on copy of all unique sequences?
purge_unique = True
# should we remove ORFs without stop codon?
purge_nostop = True
###

## ORF TRIMMING PARAMETERS
# under what length should we look for a second ORF
min_orf_len=1000 # (nts)
# what is the lowest ORF length acceptable
orf_cutoff=0.9 # (relative to average)
# sequences with proportion of undeterminate characters over the threshold will be removed
# set to 1 to not remove sequences with indetermined positions
max_indeterminate=1
# make a file with all short/nostop orfs and the initial sequence?
write_badorf=False
##

# a list of accepted continent names for metadata
# if one of these cannot be found, unknown is reported
continents=('North_America','South_America','Europe','Oceania','Africa','Asia','Antarctica')

seq_counts={}
for folder in ('temp','data','tree','metadata','annotations'):
    if not os.path.exists(f'{output_dir}/{folder}/'):
        os.mkdir(f'{output_dir}/{folder}/')
if not os.path.isfile(f'{output_dir}/metadata/override.tsv'):
    with open(f'{output_dir}/metadata/override.tsv', 'w') as f:
        f.write('this file contains overrides to the metadata, it is loaded last and overwrites anything from the other files\n')

if not os.path.isfile(f'{output_dir}/metadata/blacklist.txt'):
    with open(f'{output_dir}/metadata/blacklist.txt', 'w') as f:
        f.write('this file contains IDs that should be taken out of the final dataset\n')

if report_files==True:
    if not os.path.exists(f'{output_dir}/reports/'):
        os.mkdir(f'{output_dir}/reports/')

version='23-02-16'
# initialize modules as not having been run
alignment_run=False
tree_run=False
treetime_run=False

# %%
# this function removes illegal characters from strain names and metadata
# also strips whitespaces from front and back
def remove_illegal_chars(id):
    id=id.strip(' ')
    id = '_'.join(id.split(' '))
    # there probs is a more elegant way to do this, but its fast enough right now
    for char in ('(',')',';',':','.',",","'",'?','（','）',' '):
        id = '-'.join(id.split(char))
    return id

# this function fixes common errors in metadata and returns a formatted string
# mdata should be list date  host    host group    continent   country passage history
# species_dict should be dict species:group
def correct_mdata(strain, mdata):
    report_data=[]
    fixed_date, fixed_continent = '',''
    date_cutoff=2 # decade cut-off for 19XX or 20XX date guessing

    # fixing date
    fixed_date, report_datum=fix_date(mdata[0])
    if fixed_date=='XXXX-XX-XX':
    # no date provided, or date grivesouly misformatted
    # try to find date in strain name, else just keep as missing and output warning
        strain_date4, strain_date2=strain.rstrip('/').split('/')[-1][:4], strain.strip('/').split('/')[-1][:2]
        if len(strain_date4)==4 and strain_date4.isnumeric():
        # 4 digit number at end of strain name
            fixed_date=strain_date4+'-XX-XX'
        elif strain_date2.isnumeric():
        # no 4 digit, but 2 digit number at end of strain name
            if int(strain_date2[0])<=date_cutoff:
                fixed_date=f'20{strain_date2}-XX-XX'
            else:
                fixed_date=f'19{strain_date2}-XX-XX'

        if fixed_date != 'XXXX-XX-XX':
            report_data.append(f'{strain}: date "{mdata[0]}" could not be parsed, guessed as "{fixed_date}"')
        else:
            print(f'warning, no date for {strain}')
            report_data.append(f'WARNING no date for {strain}')
    elif report_datum != '':
        report_data.append(f'{strain}: date "{mdata[0]}" is wrong format, replaced by "{fixed_date}"')

    # fixing geography
    if remove_illegal_chars(mdata[3]) not in continents and remove_illegal_chars(mdata[4]) in continents:
        fixed_continent =f'{remove_illegal_chars(mdata[4])}\t{remove_illegal_chars(mdata[3])}'
        report_data.append(f'{strain}: fixed continent: "{mdata[3]}/{mdata[4]}" -> "{mdata[4]}/{mdata[3]}"')
    elif remove_illegal_chars(mdata[3]) not in continents and remove_illegal_chars(mdata[4]) not in continents:
        fixed_continent = f'unknown\t{remove_illegal_chars(mdata[4])}' 
        report_data.append(f'{strain}: fixed continent: "{mdata[3]}/{mdata[4]}" -> "unknown/{mdata[4]}"')
    else:
        fixed_continent = f'{remove_illegal_chars(mdata[3])}\t{remove_illegal_chars(mdata[4])}'
    return(f'{fixed_date}\t{mdata[1]}\t{mdata[2]}\t{fixed_continent}\t{mdata[5]}', report_data)

def fix_date(date):
    months=('jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec')
    d=date.split('-')
    date_fixed=date
    if ''.join(d).isnumeric():
    # only numbers, good sign
        if len(date)<10:
        # lower precision date
            if len(d[0])!=4:
            # MM-YYYY format probably??? turn around
                date_fixed=f"{d[1]}-{d[0]}"
        elif int(d[1])>12:
        # looks like 10 character date but in US format
            date_fixed=f'{d[0]}-{d[2]}-{d[1]}'

        elif len(d[2])==4:
        # date in DD-MM-YYYY
            date_fixed=f"{d[2]}-{d[1]}-{d[0]}"   
    elif len(d)>1:
    # letters in date, uh oh, but at least several fields
        if len(d)==3 and  d[1].lower() in months:
        # three letter code for month DD-MMM-YYYY or YYYY-MMM-DDDformat
            if len(d[0])==4:
            # YYYY-MMM-DD
                date_fixed=f'{d[0]}-{months.index(d[1].lower())+1:02}-{d[2]}'
            elif len(d[2])==4:
            # DD-MMM-YYYY
                date_fixed=f'{d[2]}-{months.index(d[1].lower())+1:02}-{d[0]}'
            else:
                date_fixed='XXXX-XX-XX'
        elif len(d)==2:
            if d[0].lower() in months and len(d[1])==4:
            # MMM-YYYY
                date_fixed=f'{d[1]}-{months.index(d[0].lower())+1:02}-XX'
            elif d[1].lower() in months and len(d[0])==4:
            # YYYY-MMM
                date_fixed=f'{d[0]}-{months.index(d[1].lower())+1:02}-XX'
            else:
                date_fixed='XXXX-XX-XX'
        else:  
        # no clue, just try to grab a year from strain name
            for part in d:
                if len(part)==4 and part.isnumeric():
                # this one should be the year, else would not have 4 digits
                    date_fixed=part+'-XX-XX'
                    break
            else:
            # can't find a 4 digit year, either missing date or grievously misformatted
                date_fixed='XXXX-XX-XX'
    else:
    # not numeric and just one field?! no clue
        date_fixed='XXXX-XX-XX'

    # everything should be numbers or XXXX by now, just pad it all in case it's needed
    while len(date_fixed)<10:
        date_fixed+='-XX'

    return(date_fixed, f'"{date}" -> "{date_fixed}"' if date!=date_fixed.rstrip('-XX') else '')

def inderterminate_ratio(seq):
    return(sum([0 if c in ('A','T','C','G') else 1 for c in seq])/len(seq))

# %% [markdown]
# # 1. Merging files

# %% [markdown]
# ### Renaming
# Standardizing fasta id format into a GISAID-like \<subtype\>|\<accession number\>|\<strain name\>. For GISAID, sequences without accession number will have the EPI number instead
#
# Also concatenates the sequences into a single temp file.

# %%
# re-initialize counter
seq_counts['total']=0

with open(f'{output_dir}/temp/{name}_all.fasta','w') as fout:
    for file in seq_files:
        
        if file[1]=='GISAID':
            for record in SeqIO.parse(file[0], 'fasta'):
                rec_split=record.id.split('|')
                if rec_split[1]!='':
                # has an accession number
                    record_id=f'{rec_split[0][4:]}|{rec_split[1]}|{rec_split[2]}|'
                else:
                # has no accession number  
                    record_id=f'{rec_split[0][4:]}|EPI{rec_split[3]}|{rec_split[2]}|'
                fout.write(f'>{record_id}\n{record.seq}\n')
                seq_counts['total']+=1
       
        elif file[1]=='BVBRC':
            # easiest way to deal with these is actually reading in metadata
            # the fasta is formatted by idiots  >:(
            # dict is accession_number:(subtype, strain name)
            record_ids={}
            for metafile in metadata_files:
                if metafile[1]=='BVBRC':
                    with open(metafile[0], 'r') as f:
                        f.readline()
                        for line in f:
                            l=line.split('\t')
                            record_ids[l[43][1:-1]]=f"{l[21][1:-1]}{'Nx' if len(l[21][1:-1])==2 else ''}|{l[43][1:-1]}|{'_'.join(l[15][1:-1].split(' '))}|**gb"
            for record in SeqIO.parse(file[0], 'fasta'):
                fout.write(f'>{record_ids[record.id[5:]]}\n{record.seq}\n')
                seq_counts['total']+=1
        else:
            print(f'cannot recognize {file[1]} format for {file[0]}, has to be GISAID or BVBRC, skipping')
print(f'combined sequence total: {seq_counts["total"]}')
# Out:
# combined sequence total: 24362

# %% [markdown]
# ### First de-duplication round
# Here we only remove sequences that are 100% identical and with the same accession number/strain name. This is done in 2 rounds, first looks for duplicate accession numbers, second for duplicate strain names. I am assuming that all sequences with the same accession number are identical, I don't actually check for it. For strain names it gets more complicated since the sequences might differ.
#
# BVBRC agrees with Genbank while GISAID seems to make mistakes, so the former is prioritised. Additionally if a Genbank sequence is updated, GISAID does not update the entry while BVBRC does (I think? IRD used to).

# %%
# re-initialize counter
seq_counts['dedup']=0
blacklist=[]
db_counts={'gisaid':0,'both':0,'bvbrc':0}
report_data={}

id_dict=defaultdict(list)
with open(f'{output_dir}/temp/{name}_all.fasta','r') as f:
    # get accession number from fasta id, ignore fasta without id
    for line in f:
        if line.startswith('>'):
            an=line.split('|')[1]
            if an != '':
                id_dict[an].append(line.strip().split('|',1)[1])

for records in id_dict.values():
    if len(records)>1:
        if ''.join(records).count('**gb')==1:
        # only one seq from BVBRC, keep that one
            k=''
            v=[]
            db_counts['both']+=1
            for record in records:
                if '**gb' not in record:
                    blacklist.append(record)
                    v.append(record)
                else:
                    k=record
            report_data[k]=v

        elif ''.join(records).count('**gb')==0:
        # only GISAID seqs, keep first
            blacklist+=records[1:]
            report_data[records[0]]=records[1:]
        
        else:
        # several BVBRC, keep first
            if ''.join(records).count('**gb')!=len(records):
            # at least one GISAID
                db_counts['both']+=1
            for record in records:
                if '**gb' in record:
                    records.remove(record)
                    report_data[record]=records
                    break
            blacklist+=records

# weed out first batch
seqs_to_keep=defaultdict(list)
with open(f'{output_dir}/temp/{name}_id_filtered.fasta', 'w') as f:
    for record in SeqIO.parse(f'{output_dir}/temp/{name}_all.fasta', 'fasta'):
        if record.id.split('|',1)[1] in blacklist:
        # found a blacklisted record, remove one entry in blacklist
        # this is important if the same seq is present several times
        # if we don't remove we keep none of them
            blacklist.remove(record.id.split('|',1)[1])
        else:
            if '**gb' not in record.id:
                db_counts['gisaid']+=1
            else:
                db_counts['bvbrc']+=1
            seq_counts['dedup']+=1
            f.write(f'>{record.id}\n{record.seq}\n')

if report_files == True:
# put out file with dupe info
    with open(f'{output_dir}/reports/deduplication.txt', 'w') as f:
        f.write('kept\treplaces\n')
        for k,v in report_data.items():
            f.write(f'{k}\t{",".join(v)}\n')

print(f'found and removed {seq_counts["total"]-seq_counts["dedup"]} duplicate sequences ({(seq_counts["total"]-seq_counts["dedup"])/seq_counts["total"]*100:.2f}%)')
print(f"final set contains {db_counts['gisaid']+db_counts['bvbrc']} sequences,"+
      f" of which {db_counts['gisaid']} from GISAID ({db_counts['gisaid']/(db_counts['gisaid']+db_counts['bvbrc'])*100:.2f}%)"+
      f" and {db_counts['bvbrc']} from BVBRC ({db_counts['bvbrc']/(db_counts['bvbrc']+db_counts['gisaid'])*100:.2f}%),"+
      f" {db_counts['both']} of which were also in GISAID ({db_counts['both']/db_counts['bvbrc']*100:.2f}%)")
if report_files==True:
    print(f'wrote IDs of duplicates to {output_dir}/reports/deduplication.txt')
# Out:
# found and removed 6089 duplicate sequences (24.99%)
# final set contains 18273 sequences, of which 8611 from GISAID (47.12%) and 9662 from BVBRC (52.88%), 6089 of which were also in GISAID (63.02%)
# wrote IDs of duplicates to /Users/threecats/Data/FluSeq/trees/h5_all/reports/deduplication.txt

# %% [markdown]
# # 2. Fixing and formatting metadata

# %% [markdown]
# GISAID metadata is downloaded as xlsx file and has been converted to tsv. Sadly some people put characters into the metadata that break the whole process so first we have to fix it.<p>
# BVBRC metadata just gets concatenated and the quotation marks removed

# %%
with open(f'{output_dir}/metadata/GISAID_fixed.tsv', 'w') as fout:
    # write header
    fout.write('Isolate_Id\tPB2 Segment_Id\tPB1 Segment_Id\tPA Segment_Id\tHA Segment_Id\tNP Segment_Id\tNA Segment_Id\tMP Segment_Id\tNS Segment_Id\tHE Segment_Id\tP3 Segment_Id\tIsolate_Name\tSubtype\tLineage\tPassage_History\tLocation\tHost\tIsolate_Submitter\tSubmitting_Lab\tSubmitting_Sample_Id\tAuthors\tPublication\tOriginating_Lab\tOriginating_Sample_Id\tCollection_Date\tNote\tUpdate_Date\tSubmission_Date\tAntigen_Character\tAnimal_Vaccin_Product\tAdamantanes_Resistance_geno\tOseltamivir_Resistance_geno\tZanamivir_Resistance_geno\tPeramivir_Resistance_geno\tOther_Resistance_geno\tAdamantanes_Resistance_pheno\tOseltamivir_Resistance_pheno\tZanamivir_Resistance_pheno\tPeramivir_Resistance_pheno\tOther_Resistance_pheno\tHost_Age\tHost_Age_Unit\tHost_Gender\tPatient_Status\tZip_Code\tOutbreak\tPathogen_Test_Info\tIs_Vaccinated\tHuman_Specimen_Source\tAnimal_Specimen_Source\tAnimal_Health_Status\tDomestic_Status\tPMID\tPB2 INSDC_Upload\tPB1 INSDC_Upload\tPA INSDC_Upload\tHA INSDC_Upload\tNP INSDC_Upload\tNA INSDC_Upload\tMP INSDC_Upload\tNS INSDC_Upload\tHE INSDC_Upload\tP3 INSDC_Upload')
    done={'',} # keep track of samples already added
    for file in metadata_files:
        if file[1]=='GISAID':
            with open(file[0], 'r') as fin:
                curr_line=''
                fin.readline() # skip header
                for line in fin:
                    if line.startswith('EPI_ISL_') and [l for l in line.split('\t') if l != ''][1].startswith('EPI'):
                    # a GISAID metadata line should start with EPI_ISL_ and the firsts non-empty field should start with EPI
                        if curr_line not in done:
                            fout.write('\n'+curr_line)
                            done.update(curr_line)
                        curr_line=''
                        curr_line+=line.strip()
                    else:
                        curr_line+=line.strip()
                # add last line
                if curr_line not in done:
                    fout.write('\n'+curr_line)
                if file == metadata_files[-1]:
                    fout.write('\n')

with open(f'{output_dir}/metadata/BVBRC_fixed.tsv', 'w') as fout:
    # write header
    fout.write('Genome ID\tGenome Name\tOther Names\tNCBI Taxon ID\tTaxon Lineage IDs\tTaxon Lineage Names\tSuperkingdom\tKingdom\tPhylum\tClass\tOrder\tFamily\tGenus\tSpecies\tGenome Status\tStrain\tSerovar\tBiovar\tPathovar\tMLST\tSegment\tSubtype\tH_type\tN_type\tH1 Clade Global\tH1 Clade US\tH5 Clade\tpH1N1-like\tLineage\tClade\tSubclade\tOther Typing\tCulture Collection\tType Strain\tReference\tGenome Quality\tCompletion Date\tPublication\tAuthors\tBioProject Accession\tBioSample Accession\tAssembly Accession\tSRA Accession\tGenBank Accessions\tSequencing Center\tSequencing Status\tSequencing Platform\tSequencing Depth\tAssembly Method\tChromosome\tPlasmids\tContigs\tSize\tGC Content\tContig L50\tContig N50\tTRNA\tRRNA\tMat Peptide\tCDS\tCoarse Consistency\tFine Consistency\tCheckM Contamination\tCheckM Completeness\tGenome Quality Flags\tIsolation Source\tIsolation Comments\tCollection Date\tCollection Year\tSeason\tIsolation Country\tGeographic Group\tGeographic Location\tOther Environmental\tHost Name\tHost Common Name\tHost Gender\tHost Age\tHost Health\tHost Group\tLab Host\tPassage\tOther Clinical\tAdditional Metadata\tComments\tDate Inserted\tDate Modified\n')
    done={'',} # keep track of samples already added
    for file in metadata_files:
        if file[1]=='BVBRC':
            with open(file[0], 'r') as fin:
                fin.readline() # skip header
                for line in fin:
                    if line not in done:
                        fout.write('\t'.join([l.strip('"') for l in line.strip().split('\t')])+'\n')
                        done.update(line)

# %% [markdown]
# ### Unify and filter metdata
# There's lots of fields we don't really need in the metadata and GISAID and BVBRC use completely different formats. To avoid duplicate entries, we'll also be going through the deduplicated sequence set and ensure one entry/sequence.
#
# We also take this opportunity to correct common (and easily detectable) metadata errors such as American-formatted dates and inverted countries/continents

# %%
# metadata will be read into dicts:
# strain_name:date  host    host group   continent   country passage history

report_data=[]
mdata_counts={'total':0,
              'no date':0,
              'no data':0,
              'not in species':0,
              'overrides':0,
              'overriden':0
              }
# read in species list
# expanding list of species sorted into groups
missing_species=[]
with open(species_list, 'r') as f:
    species_dict={line.strip().split('\t')[1]:line.split('\t')[0] for line in f}

# read in overrides
overrides={}
with open(f'{output_dir}/metadata/override.tsv', 'r') as f:
    f.readline() # skip header
    for line in f:
        mdata_counts['overrides']+=1
        l=line.strip().split('\t')
        overrides[l[0]]=l[1:]

# read in all GISAID data
md_gisaid={}
with open(f'{output_dir}/metadata/GISAID_fixed.tsv', 'r') as f:
    ln=1
    f.readline() # skip header
    for line in f:
        ln+=1
        l=line.split('\t')
        try:
            # figure out species group
            species=remove_illegal_chars(l[16]).lower()
            if species in species_dict.keys():
                species_group = species_dict[species]
            else:
                species_group='unknown'
                missing_species.append(species)  

            md_gisaid[remove_illegal_chars(l[11])]=[l[24], l[16], species_group, l[15].split(' / ')[0].strip('"'), l[15].split(' / ')[1].strip('"') if len(l[15].split(' / '))>1 else '', l[14]]
        except IndexError:
            print(f'warning, GISAID metadata line {ln} is too short (length {len(l)}), skipping ')

# read in all BVBRC data
md_bvbrc={}
with open(f'{output_dir}/metadata/BVBRC_fixed.tsv', 'r') as f:
    ln=1
    f.readline() # skip header
    for line in f:
        ln+=1
        l=line.split('\t')
        try:
            # figure out species group
            species=remove_illegal_chars(l[74]).lower().split('-_gender')[0]
            if species in species_dict.keys():
                species_group = species_dict[species]
            else:
                species_group='unknown'
                missing_species.append(species)

            md_bvbrc[remove_illegal_chars(l[15])]=[l[67], l[74], species_group, l[71].strip('"'), l[70].strip('"'), l[81]]
        except IndexError:
            print(f'warning, BVBRC metadata line {ln} is too short (length {len(l)}), skipping ')
        
# go through sequences, grab mdata, CORRECT, and put to file
with open(f'{output_dir}/metadata/mdata.tsv', 'w') as f:
    f.write('name\tdate\thost\thost group\tcontinent\tcountry\tpassage history\n')
    for record in SeqIO.parse(f'{output_dir}/temp/{name}_id_filtered.fasta', 'fasta'):
        mdata_counts['total']+=1
        strain=remove_illegal_chars(record.id.split('|')[2])

        if remove_illegal_chars(record.id) in overrides.keys():
        # there's an override for this sequence
            mdata='\t'.join(overrides[remove_illegal_chars(record.id)])
            f.write(f'{remove_illegal_chars(record.id)}\t{mdata}\n')
            mdata_counts['overriden']+=1
            continue
        if '**gb' in record.id:
        # use BCBRV metadata
            if strain not in md_bvbrc.keys():
                print(f'no BVBRC entry for {record.id}')
                report_data.append(f'WARNING {strain}: no metadata found in {output_dir}/metadata/BVBRC_fixed.tsv')
                mdata='XXXX-XX-XX\tunknown\tunknown\tunknown\tunknown\tunknown'
                mdata_counts['no data']+=1
            else:
                if corr_mdata==True:
                    mdata, report_datum=correct_mdata(strain,md_bvbrc[strain])
                    report_data+=report_datum
                    if mdata.split('\t')[0]=='XXXX-XX-XX':
                        mdata_counts['no date']+=1
                    if mdata.split('\t')[2]=='unknown':
                        mdata_counts['not in species']+=1
                else:
                    mdata='\t'.join(md_bvbrc[strain])
        else:
        # use GISAID metadata
            if strain not in md_gisaid.keys():
                print(f'no GISAID entry for {record.id}')
                report_data.append(f'WARNING {strain}: no metadata found in {output_dir}/metadata/GISAID_fixed.tsv')
                mdata='XXXX-XX-XX\tunknown\tunknown\tunknown\tunknown\tunknown'
                mdata_counts['no data']+=1
            else:
                if corr_mdata==True:
                    mdata, report_datum=correct_mdata(strain,md_gisaid[strain])
                    report_data+=report_datum
                    if mdata.split('\t')[0]=='XXXX-XX-XX':
                        mdata_counts['no date']+=1
                    elif int(mdata.split('\t')[0][:4])<1950 or int(mdata.split('\t')[0][:4])>int(str(date.today())[:4]):
                            print(f"{strain} has a suspiciously early/late date: {remove_illegal_chars(record.id)}\t{mdata}")
                    if mdata.split('\t')[2]=='unknown':
                        mdata_counts['not in species']+=1
                else:
                    mdata='\t'.join(md_gisaid[strain])
        f.write(f'{remove_illegal_chars(record.id)}\t{mdata}\n')

if missing_species!=[] and report_data==True:
    with open(f'{output_dir}/reports/missing_species.tsv', 'r') as f:
        for species in set(missing_species):
            f.write(f'\t{species}\n')
            print(f'no species list entry for {species}')



if report_data != [] and report_files==True:
    with open(f'{output_dir}/reports/metadata_correction.txt', 'w') as f:
        for report in report_data:
            f.write(report+'\n')
# Out:
# no GISAID entry for H5N1|EPI2245679|A/chicken/Ecuador/NIC-INSPI-AGROCALIDAD-FBC-2/2022|
# warning, no date for A/duck/Moscow/mDk364_1
# warning, no date for A/duck/Moscow/mDk364_1
# warning, no date for A/duck/Moscow/mDk13
# warning, no date for A/duck/Moscow/mDk364_1
# warning, no date for A/duck/Moscow/mDk13
# warning, no date for A/duck/Moscow/mDk4F11
# warning, no date for A/duck/Moscow/mDk4F11
# warning, no date for A/duck/Moscow/mDk13
# warning, no date for A/duck/Moscow/mDk13

# %% [markdown]
# # 3. Final filtering of sequences and ORF finding
# Here we do a bunch of things at once:
# - Find ORFs for all sequences and filter out sequences without stop codon or with short ORFs
# - Filter illegal characters from sequence names
# - Filter out sequences with no medata or no date information (optional)
# - Filter out 100% identical ORFs and only keep the earliest occurence (optional)
# - Filter out ORFs with too many inderterminate positions (optional)

# %%
# initializing counters/lists
i = 0
orfgood = [] # these are ORFs with a start and a stop
orfbad = [] # these are ORFS with a start and a stop but smaller than 90% of the average ORF or
            # or ORFs without stop codon
mdata_counts['overrides']=0
orf_counters={'nostop':0,
              'short':0,
              'no_mdata':0,
              'too_many_ind':0,
              'dupes':0,
              'kept':0}

# read in sequences
in_seqs=SeqIO.index(f'{output_dir}/temp/{name}_id_filtered.fasta', "fasta")

# read in metadata
mdata={}
with open(f'{output_dir}/metadata/mdata.tsv', 'r') as f:
    f.readline() # skip header
    for line in f:
        l=line.strip().split('\t')
        mdata[l[0]]=l[1:]


for record in SeqIO.parse(f'{output_dir}/temp/{name}_id_filtered.fasta', 'fasta'): # iterating through sequences
    if purge_nomdata == True and remove_illegal_chars(record.id) not in mdata.keys():
    # no metadata
        orfbad.append((record.id, 'no_mdata', record.seq))
        orf_counters['no_mdata']+=1
    elif purge_nomdata == True and mdata[remove_illegal_chars(record.id)][0]== 'XXXX-XX-XX':
    # no date
        orfbad.append((record.id, 'no_date', record.seq))
        orf_counters['no_mdata']+=1
    else:
    # everything ok, proceed to find ORFs
        seq = record.seq[record.seq.upper().find("ATG"):] # trim 5' end by finding first ATG and slicing 
        
        while len(seq) % 3 != 0: # making seq length a multiple of 3 so biopython doesn't yell at me (Ns will get cut off in next step)
            seq += "N"
        
        seq = seq[:len(seq.translate(to_stop=True))*3+3] # trim 3' end by slicing everything after the stop codon

        # sometimes the first ATG is not the right one, this part also tests the second ATG
        # if the orf from the first was too short
        if len(seq) < min_orf_len: 
            seq2 = record.seq[record.seq[record.seq.upper().find("ATG")+3:].upper().find('ATG')+record.seq.upper().find("ATG")+3:]
            while len(seq2) % 3 !=0 :
                seq2 += "N"
            seq2 = seq2[:len(seq2.translate(to_stop=True))*3+3]
            # if this ORF is longer, replace the previous small one by this one
            if len(seq2) > len(seq):
                seq = seq2

        if purge_nostop==True and seq.translate()[-1:] != "*": # check for stop codon at the end of ORF
            orfbad.append((record.id,'nostop', seq))
            orf_counters['nostop']+=1
        else: # either we're not checking or there is a stop codon
            orfgood.append((record.id,seq))

## sort out short ORFs (90% cut-off)
# 90% is arbitrary, adjust as desired
orf_cutoff_nts = sum([len(orf[1]) for orf in orfgood])/len(orfgood)*orf_cutoff

# turn orfgood inside out to group ids from identical sequences:
orfids=defaultdict(list)
for orf in orfgood:
    orfids[orf[1].upper()].append(orf[0])

replaced=[]
with open(f'{output_dir}/temp/{name}_unique_orfs.fasta', "w") as f:
    for seq in orfids.keys(): # iterate through unique sequences
        if inderterminate_ratio(seq.upper())<max_indeterminate:
        # check indeterminate character ratio
            # check for length, if bad set aside
            if len(seq) < orf_cutoff_nts:
            # check for length, if bad set aside
                for seqid in orfids[seq]:
                    orfbad.append((seqid, 'short', seq))
                    orf_counters['short']+=1
            else:
            # length is ok
                if purge_unique == True:
                    if len(orfids[seq])>1:
                    # not unique sequence, figure out which to keep
                        v=[remove_illegal_chars(seqid) for seqid in orfids[seq]]
                        # find the sequence with earliest date
                        # for incomplete dates, first day of first month is taken
                        earliest_id =v[[datetime.fromisoformat('-01'.join(mdata[seqid][0].split('-XX'))) for seqid in v].index(min([datetime.fromisoformat('-01'.join(mdata[seqid][0].split('-XX'))) for seqid in v]))]
                        v.remove(earliest_id)
                        f.write(f">{remove_illegal_chars(earliest_id)}\n{seq}\n")
                        replaced.append(f"{earliest_id}\t{','.join(v) if len(v)>1 else v[0]}\n")
                        orf_counters['kept']+=1
                        orf_counters['dupes']+=len(v)
                    else:
                        f.write(f'>{remove_illegal_chars(orfids[seq][0])}\n{seq}\n')
                        orf_counters['kept']+=1

                else:
                # we don't care about uniques
                    for seqid in orfids[seq]:
                        f.write(f">{remove_illegal_chars(seqid)}\n{seq}\n")
        else:
        # too many indeterminate characters
            orfbad.append((orf[0], f'too_many_ind-{inderterminate_ratio(orf[1].upper())}', orf[1]))
            orf_counters['too_many_ind']+=1


# reporting on data
print(f'looked for orfs in {sum(orf_counters.values())} sequences:')
print(f"\t{sum(orf_counters.values())-orf_counters['kept']:>6} ({(sum(orf_counters.values())-orf_counters['kept'])/sum(orf_counters.values())*100:5.2f}%) sequences discarded")
if purge_nomdata==True:
    print(f"\t\t{orf_counters['no_mdata']:>6} ({orf_counters['no_mdata']/sum(orf_counters.values())*100:5.2f}%) had no associated metadata or date")
print(f"\t\t{orf_counters['short']:>6} ({orf_counters['short']/sum(orf_counters.values())*100:5.2f}%) were shorter than {orf_cutoff*100:.0f}% of the average ({orf_cutoff_nts:.0f})")
if purge_nostop==True:
    print(f"\t\t{orf_counters['nostop']:>6} ({orf_counters['nostop']/sum(orf_counters.values())*100:5.2f}%) had no stop codon")
if max_indeterminate!=1:
    print(f"\t\t{orf_counters['too_many_ind']:>6} ({orf_counters['too_many_ind']/sum(orf_counters.values())*100:5.2f}%) had over {max_indeterminate*100:.0f}% indeterminate posiions")
if purge_unique==True:
    print(f"\t\t{orf_counters['dupes']:>6} ({orf_counters['dupes']/sum(orf_counters.values())*100:5.2f}%) were not unique")
print(f"\t{orf_counters['kept']:>6} ({(orf_counters['kept'])/sum(orf_counters.values())*100:5.2f}%) sequences kept and written to {output_dir}/{name}_unique_orfs.fasta")

if report_files==True:
    # sift through all the stuff we exluded
    orfbad_output=[]
    with open(f'{output_dir}/reports/bad_orfs.tsv', 'w') as f:
        for orf in orfbad:
            if orf[1] in ('nostop', 'short'):
                orfbad_output.append(orf)
                detail=len(orf[2])
            elif orf[1]=='too_many_ind':
                detail=f'{inderterminate_ratio(orf[2]):.2f}'
            else:
                detail=''
            f.write(f'{orf[0]}\t{orf[1]}\t{detail}\n')
    
    if orfbad_output!=[] and write_badorf==True:
        with open(f'{output_dir}/temp/{name}_orfs_bad.fasta', "w") as f2:
            for item in orfbad_output:
                f2.write(f'>{item[0]}_{item[1]}\n{item[2]}\n')
                f2.write(f'>{item[0]}\n{str(in_seqs[item[0]].seq)}\n')

    # report on replacements
    with open(f'{output_dir}/reports/replaced.tsv', 'w') as f:
        for item in replaced:
            f.write(item)
# Out:
# looked for orfs in 18273 sequences:
# 	  7225 (39.54%) sequences discarded
# 		    10 ( 0.05%) had no associated metadata or date
# 		   519 ( 2.84%) were shorter than 90% of the average (1485)
# 		  1617 ( 8.85%) had no stop codon
# 		  5079 (27.80%) were not unique
# 	 11048 (60.46%) sequences kept and written to /Users/threecats/Data/FluSeq/trees/h5_all/allH5_unique_orfs.fasta

# %% [markdown]
# ## Blacklist filtering

# %%
report_data=[]
# read in blacklist
with open(f'{output_dir}/metadata/blacklist.txt', 'r') as f:
    f.readline() # skip header
    blacklist=[remove_illegal_chars(line.strip().split('\t')[0]) for line in f]

with open(f'{output_dir}/data/{name}.fasta' ,'w') as f:
    for record in SeqIO.parse(f'{output_dir}/temp/{name}_unique_orfs.fasta' ,'fasta'):
        if record.id not in blacklist:
            f.write(f'>{record.id}\n{record.seq}\n')
        else:
            report_data.append(f'sequence {record.id} was in blacklist and has been removed')
            blacklist.remove(record.id)

blacklisted=len(report_data)
print(f'removed {blacklisted} blacklisted sequences, {len(blacklist)} blacklisted IDs were not found in the data')

if report_files==True:
    with open(f'{output_dir}/reports/blacklisted.txt', 'w') as f:
        for report in report_data:
            f.write(report+'\n')
        for seqid in blacklist:
            f.write(f'did not find {seqid} in data\n')
# Out:
# removed 7 blacklisted sequences, 0 blacklisted IDs were not found in the data

# %% [markdown]
# The dataset should now be ready for alignment and tree building.
#
# Of course, there's always more that can be done, starting with getting some stats on the whole process.

# %% [markdown]
# # 4. Some info and stats

# %% [markdown]
# Run this to output a file that sums up what was done to the data

# %%
with open(f'{output_dir}/parameters.txt', 'w') as f:
    f.write(f'dataset {name} was cleaned up using pépinière v{version} on {date.today()}\n')
    if report_files==True:
        f.write(f"reports were generated and written to {output_dir}/reports\n")
    else:
        f.write('no reports were generated\n')


    f.write(f'\n{"_"*60}\n')
    f.write('INPUT SEQUENCES\n')
    f.write(f'input files were: {seq_files[0][0]} ({seq_files[0][1]} format)\n')
    for seq_file in seq_files[1:]:
        f.write(f"{' '*18}{seq_file[0]} ({seq_file[1]} format)\n")
    f.write(f'\nfound and removed {seq_counts["total"]-seq_counts["dedup"]} duplicate sequences based on accession/EPI numbers ({(seq_counts["total"]-seq_counts["dedup"])/seq_counts["total"]*100:.2f}%)\n')
    f.write(f"final set contains {db_counts['gisaid']+db_counts['bvbrc']} sequences,"+
        f" of which {db_counts['gisaid']} from GISAID ({db_counts['gisaid']/(db_counts['gisaid']+db_counts['bvbrc'])*100:.2f}%)"+
        f" and {db_counts['bvbrc']} from BVBRC ({db_counts['bvbrc']/(db_counts['bvbrc']+db_counts['gisaid'])*100:.2f}%),"+
        f" {db_counts['both']} of which were also in GISAID ({db_counts['both']/db_counts['bvbrc']*100:.2f}%)\n")
    

    f.write(f'\n{"_"*60}\n')
    f.write('INPUT METADATA\n')
    f.write(f'\nmetadata files were: {metadata_files[0][0]} ({metadata_files[0][1]} format)\n')
    for metadata_file in metadata_files[1:]:
        f.write(f"{' '*21}{metadata_file[0]} ({metadata_file[1]} format)\n")
    f.write(f"\nmetadata was{' not' if corr_mdata==False else ''} corrected and consolidated to {output_dir}/metadata/mdata.tsv\n")
    f.write(f"species list used was {species_list} containing {len(species_dict)} entries but missing {len(set(missing_species))} entries\n")
    f.write(f"override file contained {mdata_counts['overrides']} entries, {mdata_counts['overriden']} entries were overriden")
    f.write(f"\nof {mdata_counts['total']} processed metadata entries:\n")
    f.write(f"\t{mdata_counts['no data']:>5} had no metadata info{' '*6}({mdata_counts['no data']/mdata_counts['total']*100:5.2f}%)\n")
    f.write(f"\t{mdata_counts['no date']:>5} had no date info{' '*10}({mdata_counts['no date']/mdata_counts['total']*100:5.2f}%)\n")
    f.write(f"\t{mdata_counts['not in species']:>5} had no species group info ({mdata_counts['not in species']/mdata_counts['total']*100:5.2f}%)\n")



    f.write(f'\n{"_"*60}\n')
    f.write('ORF TRIMMING\n')
    f.write(f'looked for orfs in {sum(orf_counters.values())} sequences:\n')
    f.write(f"\t{sum(orf_counters.values())-orf_counters['kept']:>6} ({(sum(orf_counters.values())-orf_counters['kept'])/sum(orf_counters.values())*100:5.2f}%) sequences discarded\n")
    f.write(f"\t\t{orf_counters['short']:>6} ({orf_counters['short']/sum(orf_counters.values())*100:5.2f}%) were shorter than {orf_cutoff*100:.0f}% of the average ({orf_cutoff_nts:.0f})\n")
    if purge_nomdata==True:
        f.write(f"\t\t{orf_counters['no_mdata']:>6} ({orf_counters['no_mdata']/sum(orf_counters.values())*100:5.2f}%) had no associated metadata or date\n")
    else:
        f.write('\t\tsequences without metadata were not removed from the dataset\n')
    if purge_nostop==True:
        f.write(f"\t\t{orf_counters['nostop']:>6} ({orf_counters['nostop']/sum(orf_counters.values())*100:5.2f}%) had no stop codon\n")
    else:
        f.write('\t\tORFs without stop codon were not removed from the dataset\n')
    if max_indeterminate!=1:
        f.write(f"\t\t{orf_counters['too_many_ind']:>6} ({orf_counters['too_many_ind']/sum(orf_counters.values())*100:5.2f}%) had over {max_indeterminate*100:.0f}% indeterminate posiions\n")
    else:
        f.write('\t\tORFs with indeterminate positions were not removed from the dataset\n')
    if purge_unique==True:
        f.write(f"\t\t{orf_counters['dupes']:>6} ({orf_counters['dupes']/sum(orf_counters.values())*100:5.2f}%) were not unique\n")
    else:
        f.write('\t\tduplicate ORFs were not removed from the dataset\n')
    f.write(f"\t{orf_counters['kept']:>6} ({(orf_counters['kept'])/sum(orf_counters.values())*100:5.2f}%) sequences kept and written to {output_dir}/{name}_unique_orfs.fasta\n")

    if len(blacklist) != 0:
        f.write(f'\n blacklist contained {len(blacklist)} sequences, {blacklisted} of which were found and removed from the final data')

    f.write(f'\nfinal dataset contains {orf_counters["kept"]-blacklisted} of {seq_counts["total"]} sequences ({orf_counters["kept"]/seq_counts["total"]*100:.2f}%)')

# %% [markdown]
# This looks in more detail at the sequence replacement part of the script

# %%
year_ranges=Counter()
regions_counts=Counter()
species_counts=Counter()

if report_files==True:
    with open(f'{output_dir}/reports/replaced.tsv', 'r') as f:
        groups=[[line.split('\t')[0]]+line.strip().split('\t')[1].split(',') for line in f]
    with (open(f'{output_dir}/reports/heterogeneous_years.tsv', 'w') as f_years,
          open(f'{output_dir}/reports/heterogeneous_region.tsv', 'w') as f_region,
          open(f'{output_dir}/reports/heterogeneous_species.tsv', 'w') as f_species):
        f_years.write('group\tyears\tspecies\tregion\n')
        f_region.write('group\tyears\tspecies\tregion\n')
        f_species.write('group\tyears\tspecies\tregion\n')
        for group in groups:
            years=[int(mdata[seqid][0].split('-')[0]) for seqid in group]
            year_range=max(years)-min(years)
            year_ranges.update((year_range,))
            regions=[mdata[seqid][3] for seqid in group if mdata[seqid][3]!= 'unknown']
            regions_counts.update((max(0,len(set(regions))-1),))
            species=[mdata[seqid][2] for seqid in group if mdata[seqid][2] not in  ('unknown', 'not determined')]
            species_counts.update((max(0,len(set(species))-1),))

            # write to file,
            if year_range > year_gap_threshold:
                f_years.write(f"{','.join(group)}\t{','.join(map(str,years))}\t{','.join(regions)}\t{','.join(species)}\n")
            if len(set(regions))>1:
                f_region.write(f"{','.join(group)}\t{','.join(map(str,years))}\t{','.join(regions)}\t{','.join(species)}\n")
            if len(set(species))>1:
                f_species.write(f"{','.join(group)}\t{','.join(map(str,years))}\t{','.join(regions)}\t{','.join(species)}\n")
    if plotting == True:
        data=pd.DataFrame([[k, v, 'year'] for k, v in year_ranges.items()]+[[k, v, 'region'] for k, v in regions_counts.items()]+[[k, v, 'species'] for k, v in species_counts.items()],
                        columns=['differences', 'count', 'metric'])
        fig=px.bar(data, x='differences',y='count',facet_col='metric')
        fig.update_xaxes(matches=None)
        fig.show()
# Out:
# <div>                            <div id="bd73f2f0-cdbc-4705-a102-26b6359fa5ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd73f2f0-cdbc-4705-a102-26b6359fa5ed")) {                    Plotly.newPlot(                        "bd73f2f0-cdbc-4705-a102-26b6359fa5ed",                        [{"alignmentgroup":"True","hovertemplate":"metric=year<br>differences=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[0,1,2,3,19,23,6],"xaxis":"x","y":[1908,142,9,2,1,1,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"metric=region<br>differences=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[0,1],"xaxis":"x2","y":[2059,6],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"metric=species<br>differences=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[0,1,2],"xaxis":"x3","y":[1762,294,9],"yaxis":"y3","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""} ...

# %% [markdown]
# # 5. Treework

# %% [markdown]
# ## Aligning
# Try to align our dataset using MAFFT. MAFFT needs to be installed and in the path of your computer!

# %%
if toggle_align==True:
    if alignment_run==True:
        rerun=input('alignment has already been run, should i rerun it? y/n')
    else:
        rerun='y'
    if rerun == 'y':
        cmd = f"mafft --reorder --anysymbol --thread 8 --nomemsave {quote(f'{output_dir}/data/{name}.fasta')} 1> {quote(f'{output_dir}/data/{name}_mafft.fasta')}" 
        # !{cmd}
        alignment_run=True
    else:
        print(f'answer was {rerun}, alignment will not be rerun')
# Out:
# inputfile = orig
# 11041 x 1734 - 1509 d
# nthread = 8
# nthreadpair = 8
# nthreadtb = 8
# ppenalty_ex = 0
# stacksize: 8176 kb
# generating a scoring matrix for nucleotide (dist=200) ... done
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#
# There are 6352 ambiguous characters.
#  11001 / 11041 (thread    0)
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#  11030 / 11041
# done.
#
# Progressive alignment 1/2...
# STEP  10801 / 11040 (thread    3)
# Reallocating..done. *alloclen = 4469
# STEP  11001 / 11040 (thread    7) h
# done.
#
# Making a distance matrix from msa..
#  11000 / 11041 (thread    7)
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#  11030 / 11041
# done.
#
# Progressive alignment 2/2...
# STEP  10901 / 11040 (thread    1)
# Reallocating..done. *alloclen = 4482
# STEP  11001 / 11040 (thread    5)
# done.
#
# disttbfast (nuc) Version 7.515
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 8 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.

# %% [markdown]
# ## Tree making
# Calling fasttree on the alignment. Fasttree needs to be in the path of your computer!

# %%
if toggle_tree == True:
    if tree_run == True:
        rerun=input('tree was already run, should i rerun it ? y/n')
    else:
        rerun='y'
    if rerun == 'y':
        cmd= f"fasttree -nt -gtr -gamma {quote(f'{output_dir}/data/{name}_mafft.fasta')} > {quote(f'{output_dir}/tree/{name}_mafft_fast.tree')}"
        # !{cmd}
        tree_run=True
    else:
        'tree has already been made and will not be rerun'
# Out:
# FastTree Version 2.1.11 Double precision (No SSE3)
# Alignment: /Users/threecats/Data/FluSeq/trees/h5_all/data/allH5_mafft.fasta
# Nucleotide distances: Jukes-Cantor Joins: balanced Support: SH-like 1000
# Search: Normal +NNI +SPR (2 rounds range 10) +ML-NNI opt-each=1
# TopHits: 1.00*sqrtN close=default refresh=0.80
# ML Model: Generalized Time-Reversible, CAT approximation with 20 rate categories
# Ignored unknown character D (seen 1 times)
# Ignored unknown character H (seen 1 times)
# Ignored unknown character K (seen 80 times)
# Ignored unknown character M (seen 157 times)
# Ignored unknown character R (seen 1110 times)
# Ignored unknown character S (seen 27 times)
# Ignored unknown character V (seen 1 times)
# Ignored unknown character W (seen 136 times)
# Ignored unknown character X (seen 4190 times)
# Ignored unknown character Y (seen 649 times)
# Initial topology in 76.40 seconds of  11038   01 of  11041 seqs   1000)
# Refining topology: 54 rounds ME-NNIs, 2 rounds ME-SPRs, 27 rounds ML-NNIs
# Total branch-length 30.244 after 138.89 sec1 of 11039 splits   s, 29 changes (max delta 0.000)
# ML-NNI round 1: LogLk = -405044.951 NNIs 2896 max delta 18.23 Time 165.66nges (max delta 18.230)
# GTR Frequencies: 0.3485 0.1855 0.2284 0.2377ep 12 of 12
# GTR rates(ac ag at cg ct gt) 1.3880 7.4330 0.7515 0.3213 10.2660 1.0000
# Switched to using 20 rate categories (CAT approximation)20 of 20
# Rate categories were divided by 0.956 so that average rate = 1.0
# CAT-based log-likelihoods may not be comparable across runs
# Use -gamma for approximate but comparable Gamma(20) log-likelihoods
# ML-NNI round 2: LogLk = -346350.430 NNIs 3628 max delta 24.23 Time 286.21nges (max delta 24.230)
# ML-NNI round 3: LogLk = -346266.085 NNIs 2848 max delta 14.66 Time 309.13ges (max delta 14.663)
# ML-NNI round 4: LogLk = -346227.618 NNIs 2362 max delta 19.26 Time 327.01ges (max delta 19.259)
# ML-NNI round 5: LogLk = -346216.743 NNIs 2065 max delta 9.64 Time 341.49nges (max delta 9.640)
# ML-NNI round 6: LogLk = -346213.118 NNIs 1765 max delta 1.48 Time 353.40nges (max delta 1.476)
# ML-NNI round 7: LogLk = -346211.392 NNIs 1660 max delta 1.72 Time 364.63nges (max delta 1.724)
# ML-NNI round 8: LogLk = -346211.388 NNIs 1492 max delta 0.00 Time 374.69nges (max delta 0.000)
# Turning off heuristics for final round of ML NNIs (converged)
# ML-NNI round 9: LogLk = -346198.547 NNIs 2654 max delta 4.40 Time 407.51 (final)ax delta 4.402)
# Optimize all lengths: LogLk = -346198.297 Time 415.33
# Total time: 461.61 seconds Unique: 11041/11041 Bad splits: 1/11038 Worst delta-LogLk 0.362

# %% [markdown]
# ## Treetime
# Calling treetime on the alignment, tree and metadata. Generate a newick format tree that can be uploaded to iTOL (which does not like the default nexus output tree). Treetime needs to be in the path of your computer!

# %%
if toggle_treetime==True:
    # first we need to actually incorporate the metadata override into the metadata file
    if treetime_run==True:
        rerun=input('treetime was already called, should i rerun it? y/n')
    else:
        rerun='y'
    if rerun=='y':
        cmd = f"treetime --aln {quote(f'{output_dir}/data/{name}_mafft.fasta')} --tree {quote(f'{output_dir}/tree/{name}_mafft_fast.tree')} --dates {quote(f'{output_dir}/metadata/mdata.tsv')} --outdir {quote(f'{output_dir}/tree/')}"
        # !{cmd}
        treetime_run=True
        with open(f'{output_dir}/tree/timetree.nexus', 'r') as fin, open(f'{output_dir}/tree/fasttimetree.nwk', 'w') as fout:
            for line in fin:
                if line.startswith(' Tree tree1='):
                    fout.write(line.split('tree1=')[1])
# Out:
# Attempting to parse dates...
# 	Using column 'name' as name. This needs match the taxon names in the tree!!
# 	Using column 'date' as date.
#
# 0.00	-TreeAnc: set-up
#
# 21.06	-WARNING: character U is unknown. Treating it as missing information
#
# 21.78	WARNING: Previous versions of TreeTime (<0.7.0) RECONSTRUCTED sequences of
#      	tips at positions with AMBIGUOUS bases. This resulted in unexpected
#      	behavior is some cases and is no longer done by default. If you want to
#      	replace those ambiguous sites with their most likely state, rerun with
#      	`reconstruct_tip_states=True` or `--reconstruct-tip-states`.
#
# 86.89	TreeTime.reroot: with method or node: least-squares
#
# 86.96	TreeTime.reroot: rerooting will ignore covariance and shared ancestry.
#
# 105.22	TreeTime.reroot: with method or node: least-squares
#
# 105.29	TreeTime.reroot: rerooting will ignore covariance and shared ancestry.
#
# 144.26	###TreeTime.run: INITIAL ROUND
#
# 324.89	TreeTime.reroot: with method or node: least-squares
#
# 324.97	TreeTime.reroot: rerooting will ignore covariance and shared ancestry.
#
# 339.57	###TreeTime.run: rerunning timetree after rerooting
#
# 544.97	###TreeTime.run: ITERATION 1 out of 2 iterations
#
# 831.71	###TreeTime.run: ITERATION 2 out of 2 iterations
#
# 1116.21	TreeTime: the following tips have been marked as outliers. Their date
#        	constraints were not used. Please remove them from the tree. Their dates
#        	have been reset:
#
# 1116.21	H5N2|AB753185|A/Eurasian_Woodcock/Vietnam/8/2007|**gb, input date:
#        	[2007.8342465753424, 2007.9136986301369], apparent date: 2007.18
#
# 1116.21	H5N2|EPI579003|A/chicken/NL-Bruchem/14003323/2014|, input date:
#        	2014.1931506849314, apparent date: 2011.15
#
# 1116.21	H5N2|CY146676|A/duck/Hunan/S4124/2011|**gb, input date:
#        	2011.8616438356164, apparent date: 2008.05
#
# 1116.21	H5N2|CY146668|A/duck/Hunan/S4120/2011|**gb, input date:
#        	2011.8616438356164, apparent date: 2007.95
#
# 1116.21	H5N2|CY146652|A/duck/Hunan/S4101/2011|**gb, input date:
#        	2011.8616438356164, apparent date: 2008.05
#
# 1116.21	H5N2|CY178647|A/mallard/Saskatchewan/17/1981|**gb, input date:
#        	[1981.0013698630137, 1981.9986301369863], apparent date: 1988.20
#
# 1116.21	H5N2|CY178102|A/mallard/Wisconsin/598/1983|**gb, input date:
#        	[1983.0013698630137, 1983.9986301369863], apparent date: 1988.72
#
# 1116.22	H5N2|CY014722|A/duck/Minnesota/1516/1981|**gb, input date:
#        	1981.7739726027398, apparent date: 1988.71
#
# 1116.22	H5N2|EU743600|A/turkey/TX/1-40-82/1982|**gb, input date:
#        	[1982.0013698630137, 1982.9986301369863], apparent date: 1989.43
#
# 1116.22	H5N2|CY014872|A/black_duck/New_York/184/1988|**gb, input date:
#        	[1988.0013661202186, 1988.9986338797814], apparent date: 1992.91
#
# 1116.22	H5N3|AB558462|A/turkey/California/21860/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1989.35
#
# 1116.22	H5N3|EPI860453|A/whistling_swan/Shimane/467/83|, input date:
#        	[1983.0013698630137, 1983.9986301369863], apparent date: 1989.10
#
# 1116.22	H5N2|CY180388|A/mallard/Wisconsin/232/1976|**gb, input date:
#        	[1976.0013661202186, 1976.9986338797814], apparent date: 1991.47
#
# 1116.22	H5N2|CY005918|A/mallard_duck/ALB/57/1976|**gb, input date:
#        	1976.613387978142, apparent date: 1993.28
#
# 1116.22	H5N3|EU743301|A/turkey/CA/6878/1979|**gb, input date:
#        	[1979.0013698630137, 1979.9986301369863], apparent date: 1995.05
#
# 1116.22	H5N2|CY014580|A/mallard_duck/Alberta/645/1980|**gb, input date:
#        	1980.6407103825136, apparent date: 1995.09
#
# 1116.22	H5N2|EF607857|A/blue_goose/WI/711/1975|, input date:
#        	[1975.0013698630137, 1975.9986301369863], apparent date: 1993.99
#
# 1116.22	H5N2|CY179763|A/mallard/Alabama/847/1975|**gb, input date:
#        	[1975.0013698630137, 1975.9986301369863], apparent date: 1993.05
#
# 1116.22	H5N2|CY014640|A/duck/New_Zealand/41/1984|**gb, input date:
#        	1984.1079234972678, apparent date: 2003.45
#
# 1116.22	H5N9|M30122|A/turkey/Ontario/7732/1966|, input date:
#        	[1966.0013698630137, 1966.9986301369863], apparent date: 2000.41
#
# 1116.22	H5N9|AB558456|A/turkey/Ontario/7732/1966|**gb, input date:
#        	[1966.0013698630137, 1966.9986301369863], apparent date: 2000.35
#
# 1116.22	H5N9|HE802064|A/turkey/Wisconsin/1968|**gb, input date:
#        	[1968.0013661202186, 1968.9986338797814], apparent date: 1998.46
#
# 1116.22	H5N9|CY080507|A/turkey/Wisconsin/1/1968|**gb, input date:
#        	1968.4439890710382, apparent date: 1998.36
#
# 1116.22	H5N2|GU186482|A/turkey/CO/118899/1972|**gb, input date:
#        	[1972.0013661202186, 1972.9986338797814], apparent date: 2000.78
#
# 1116.22	H5N2|CY180380|A/blue-winged_teal/Wisconsin/231/1976|**gb, input date:
#        	[1976.0013661202186, 1976.9986338797814], apparent date: 2001.60
#
# 1116.22	H5N2|CY180540|A/green-winged_teal/Wisconsin/103/1976|**gb, input date:
#        	[1976.0013661202186, 1976.9986338797814], apparent date: 2001.50
#
# 1116.22	H5N2|CY180532|A/duck/Minnesota/63/1976|**gb, input date:
#        	[1976.0013661202186, 1976.9986338797814], apparent date: 2001.30
#
# 1116.22	H5N2|EU743293|A/mallard/WI/42/1975|**gb, input date:
#        	[1975.0013698630137, 1975.9986301369863], apparent date: 2001.42
#
# 1116.22	H5N2|CY179779|A/mallard/Wisconsin/42/1975|**gb, input date:
#        	[1975.0013698630137, 1975.9986301369863], apparent date: 2001.42
#
# 1116.22	H5N2|J04325|A/chick/Pennsylvania/1/1983|, input date:
#        	[1983.0013698630137, 1983.9986301369863], apparent date: 2011.87
#
# 1116.22	H5N2|GU052787|A/chicken/Pennsylvania/21525/1983|**gb, input date:
#        	[1983.0013698630137, 1983.9986301369863], apparent date: 2011.25
#
# 1116.22	H5N2|FJ610134|A/chicken/VA/40018/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 2012.98
#
# 1116.22	H5N2|GU052779|A/chicken/Florida/27716-2/1986|**gb, input date:
#        	[1986.0013698630137, 1986.9986301369863], apparent date: 2014.59
#
# 1116.22	H5N2|GU052747|A/chicken/Pennsylvania/10210/1986|**gb, input date:
#        	[1986.0013698630137, 1986.9986301369863], apparent date: 2015.21
#
# 1116.22	H5N2|EU743233|A/goose/OH/22911-2/1986|**gb, input date:
#        	[1986.0013698630137, 1986.9986301369863], apparent date: 2015.07
#
# 1116.22	H5N2|FJ357091|A/guinea_fowl/OH/22911-20/1986|**gb, input date:
#        	[1986.0013698630137, 1986.9986301369863], apparent date: 2014.97
#
# 1116.22	H5N2|CY015073|A/chicken/Pennsylvania/1/1983|**gb, input date:
#        	[1983.0013698630137, 1983.9986301369863], apparent date: 2011.53
#
# 1116.22	H5N2|GU052771|A/chicken/Pennsylvania/1370/1983|**gb, input date:
#        	[1983.0013698630137, 1983.9986301369863], apparent date: 2011.84
#
# 1116.22	H5N2|AB558463|A/chicken/Pennsylvania/1370/1983|**gb, input date:
#        	[1983.0013698630137, 1983.9986301369863], apparent date: 2011.94
#
# 1116.22	H5N2|M10243|A/chicken/Pennsylvania/1370/1983|, input date:
#        	[1983.0013698630137, 1983.9986301369863], apparent date: 2013.18
#
# 1116.22	H5N2|M18001|A/chicken/Pennsylvania/1/1983|, input date:
#        	[1983.0013698630137, 1983.9986301369863], apparent date: 2013.85
#
# 1116.22	H5N1|CY014726|A/duck/Minnesota/1525/1981|**gb, input date:
#        	1981.7931506849316, apparent date: 1992.29
#
# 1116.22	H5N2|CY179403|A/mallard/Wisconsin/411/1981|**gb, input date:
#        	[1981.0013698630137, 1981.9986301369863], apparent date: 1992.29
#
# 1116.22	H5N2|KP674447|A/chicken/Pennsylvania/7659/1985|**gb, input date:
#        	[1985.0013698630137, 1985.9986301369863], apparent date: 1992.49
#
# 1116.22	H5N2|U79454|A/turkey/Minnesota/3689-1551/1981|, input date:
#        	[1981.0013698630137, 1981.9986301369863], apparent date: 1992.39
#
# 1116.22	H5N2|AB558457|A/turkey/Minnesota/3689-1551/1981|**gb, input date:
#        	[1981.0013698630137, 1981.9986301369863], apparent date: 1992.39
#
# 1116.22	H5N1|EU871820|A/turkey/Ontario/84/1983|**gb, input date:
#        	[1983.0013698630137, 1983.0835616438355], apparent date: 1993.00
#
# 1116.22	H5N1|CY179411|A/mallard/Wisconsin/568/1982|**gb, input date:
#        	[1982.0013698630137, 1982.9986301369863], apparent date: 1992.18
#
# 1116.22	H5N2|CY178062|A/mallard/Wisconsin/994/1982|**gb, input date:
#        	[1982.0013698630137, 1982.9986301369863], apparent date: 1992.80
#
# 1116.22	H5N2|CY014849|A/mallard_duck/New_York/189/1982|**gb, input date:
#        	1982.9164383561645, apparent date: 1992.70
#
# 1116.22	H5N2|CY178815|A/mallard/Wisconsin/984/1982|**gb, input date:
#        	[1982.0013698630137, 1982.9986301369863], apparent date: 1992.49
#
# 1116.22	H5N2|CY178078|A/mallard/Wisconsin/99/1982|**gb, input date:
#        	[1982.0013698630137, 1982.9986301369863], apparent date: 1992.70
#
# 1116.22	H5N2|CY178070|A/mallard/Wisconsin/996/1982|**gb, input date:
#        	[1982.0013698630137, 1982.9986301369863], apparent date: 1992.69
#
# 1116.22	H5N2|CY178118|A/mallard/Wisconsin/1622/1983|**gb, input date:
#        	[1983.0013698630137, 1983.9986301369863], apparent date: 1992.39
#
# 1116.22	H5N2|CY178110|A/mallard/Wisconsin/1616/1983|**gb, input date:
#        	[1983.0013698630137, 1983.9986301369863], apparent date: 1992.49
#
# 1116.22	H5N2|CY178126|A/mallard/Wisconsin/1623/1983|**gb, input date:
#        	[1983.0013698630137, 1983.9986301369863], apparent date: 1992.49
#
# 1116.22	H5N2|CY178086|A/widgeon/Wisconsin/493/1983|**gb, input date:
#        	[1983.0013698630137, 1983.9986301369863], apparent date: 1992.90
#
# 1116.22	H5N2|CY178623|A/mallard/Wisconsin/487/1983|**gb, input date:
#        	[1983.0013698630137, 1983.9986301369863], apparent date: 1993.00
#
# 1116.22	H5N2|CY178094|A/blue-winged_teal/Wisconsin/568/1983|**gb, input date:
#        	[1983.0013698630137, 1983.9986301369863], apparent date: 1992.80
#
# 1116.22	H5N3|CY005926|A/herring_gull/NJ/402/1989|**gb, input date:
#        	1989.3082191780823, apparent date: 1997.08
#
# 1116.22	H5N2|AB295603|A/duck/Pennsylvania/10218/1984|, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.21
#
# 1116.22	H5N2|AF100180|A/Mallard_Duck/Pensylvania/10218/84|, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.32
#
# 1116.22	H5N2|AF100179|A/Mallard_Duck/Pensylvania/10218/84|, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.62
#
# 1116.22	H5N2|KF006998|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.83
#
# 1116.22	H5N2|KF006997|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.83
#
# 1116.22	H5N2|GU183568|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.83
#
# 1116.22	H5N2|GU183554|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.93
#
# 1116.22	H5N2|KX879581|A/duck/Pennsylvania/10218-MA/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.83
#
# 1116.22	H5N2|GU183560|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.83
#
# 1116.22	H5N2|AF512938|A/Mallard_duck/PA/10218/84|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.83
#
# 1116.22	H5N2|GU183564|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.83
#
# 1116.22	H5N2|GU183562|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.83
#
# 1116.22	H5N2|GU183563|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.83
#
# 1116.22	H5N2|GU183567|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.93
#
# 1116.22	H5N2|GU183565|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.93
#
# 1116.22	H5N2|GU183566|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.93
#
# 1116.22	H5N2|AF512925|A/Mallard_duck/PA/10218/84|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.72
#
# 1116.22	H5N2|GU183558|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.93
#
# 1116.22	H5N2|GU183561|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.83
#
# 1116.22	H5N2|AF512931|A/Mallard_duck/PA/10218/84|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.93
#
# 1116.22	H5N2|AF512932|A/Mallard_duck/PA/10218/84|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.83
#
# 1116.22	H5N2|GU183556|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.83
#
# 1116.22	H5N2|GU183557|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1994.13
#
# 1116.22	H5N2|GU183555|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.83
#
# 1116.22	H5N2|KF006996|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.93
#
# 1116.22	H5N2|GU183559|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1994.13
#
# 1116.22	H5N2|KM226782|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.93
#
# 1116.22	H5N2|AF512939|A/Mallard_duck/PA/10218/84|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.83
#
# 1116.22	H5N2|AF512933|A/Mallard_duck/PA/10218/84|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1994.03
#
# 1116.22	H5N2|KM186131|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.93
#
# 1116.22	H5N2|AF512928|A/Mallard_duck/PA/10218/84|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.83
#
# 1116.22	H5N2|AF512940|A/Mallard_duck/PA/10218/84|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.93
#
# 1116.22	H5N2|AF512929|A/Mallard_duck/PA/10218/84|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.93
#
# 1116.22	H5N2|AF512936|A/Mallard_duck/PA/10218/84|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.93
#
# 1116.22	H5N2|KM186130|A/mallard/Pennsylvania/10218/1984|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1994.03
#
# 1116.22	H5N2|AF512926|A/Mallard_duck/PA/10218/84|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.83
#
# 1116.22	H5N2|AF512935|A/Mallard_duck/PA/10218/84|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1994.03
#
# 1116.22	H5N2|AF512934|A/Mallard_duck/PA/10218/84|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1994.13
#
# 1116.22	H5N2|AF512941|A/Mallard_duck/PA/10218/84|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1993.93
#
# 1116.22	H5N2|AF512937|A/Mallard_duck/PA/10218/84|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1994.03
#
# 1116.22	H5N2|AF512930|A/Mallard_duck/PA/10218/84|**gb, input date:
#        	[1984.0013661202186, 1984.9986338797814], apparent date: 1994.03
#
# 1116.22	H5N2|MT325931|A/Northern_shoveler/Mexico/HA_UIFMVZ613/2017|**gb, input
#        	date: 2017.154794520548, apparent date: 1994.44
#
# 1116.22	H5N2|KM368299|A/turkey/Veracruz/2579-06/2006|**gb, input date:
#        	[2006.0863013698631, 2006.1602739726027], apparent date: 2007.90
#
# 1116.22	H5N2|KM455881|A/chicken/Veracruz/1433-1/2006|**gb, input date:
#        	[2006.0013698630137, 2006.9986301369863], apparent date: 2007.45
#
# 1116.22	H5N0|EU099400|A/chicken/Guatemala/270475-1/2003|, input date:
#        	[2003.0013698630137, 2003.9986301369863], apparent date: 2005.61
#
# 1116.22	H5N0|EU099401|A/chicken/Guatemala/270475-4/2003|, input date:
#        	[2003.0013698630137, 2003.9986301369863], apparent date: 2005.92
#
# 1116.22	H5N2|OK205611|A/chicken/Guatemala/45511-4/2000|**gb, input date:
#        	[2000.0013661202186, 2000.9986338797814], apparent date: 2001.58
#
# 1116.22	H5N2|OK205531|A/chicken/El_Salvador/102711-1/2001|**gb, input date:
#        	[2001.0013698630137, 2001.9986301369863], apparent date: 2002.74
#
# 1116.22	H5N2|OK205539|A/chicken/El_Salvador/102711-2/2001|**gb, input date:
#        	[2001.0013698630137, 2001.9986301369863], apparent date: 2003.15
#
# 1116.22	H5N2|GU052636|A/chicken/El_Salvador/102711-2/2001|**gb, input date:
#        	[2001.0013698630137, 2001.9986301369863], apparent date: 2003.26
#
# 1116.22	H5N2|KM368279|A/chicken/Mexico/4188-05/2005|**gb, input date:
#        	[2005.4150684931508, 2005.4945205479453], apparent date: 2006.72
#
# 1116.22	H5N2|KM368281|A/chicken/Queretaro/6535-05/2005|**gb, input date:
#        	[2005.16301369863, 2005.2452054794521], apparent date: 2005.96
#
# 1116.22	H5N2|KM368294|A/chicken/Queretaro/0092-06/2006|**gb, input date:
#        	[2006.0013698630137, 2006.0835616438355], apparent date: 2007.74
#
# 1116.22	H5N2|KM368284|A/chicken/Durango/7035-05/2005|**gb, input date:
#        	[2005.7493150684932, 2005.831506849315], apparent date: 2010.08
#
# 1116.22	H5N2|KM368274|A/chicken/Queretaro/1939-05/2005|**gb, input date:
#        	[2005.16301369863, 2005.2452054794521], apparent date: 2007.47
#
# 1116.22	H5N2|KM368275|A/chicken/Coahuila/2675-05/2005|**gb, input date:
#        	[2005.2479452054795, 2005.327397260274], apparent date: 2006.72
#
# 1116.22	H5N2|KM455889|A/chicken/Durango/1433-4/2005|**gb, input date:
#        	[2005.0013698630137, 2005.9986301369863], apparent date: 2007.97
#
# 1116.22	H5N2|KM368300|A/chicken/Coahuila/2936-06/2006|**gb, input date:
#        	[2006.16301369863, 2006.2452054794521], apparent date: 2010.00
#
# 1116.22	H5N2|KM368292|A/chicken/Durango/1555-06/2006|**gb, input date:
#        	[2006.0863013698631, 2006.1602739726027], apparent date: 2007.76
#
# 1116.22	H5N2|KM455954|A/chicken/Durango/1433-14/2006|**gb, input date:
#        	[2006.0013698630137, 2006.9986301369863], apparent date: 2007.76
#
# 1116.22	H5N2|KM368277|A/chicken/Durango/3717-05/2005|**gb, input date:
#        	[2005.4150684931508, 2005.4945205479453], apparent date: 2006.87
#
# 1116.22	H5N2|KM455950|A/chicken/Durango/1433-2/2005|**gb, input date:
#        	[2005.0013698630137, 2005.9986301369863], apparent date: 2006.97
#
# 1116.22	H5N2|KM368276|A/chicken/Durango/2678-05/2005|**gb, input date:
#        	[2005.2479452054795, 2005.327397260274], apparent date: 2007.48
#
# 1116.22	H5N2|KM368278|A/chicken/Coahuila/3739-05/2005|**gb, input date:
#        	[2005.4150684931508, 2005.4945205479453], apparent date: 2007.38
#
# 1116.22	H5N2|KM455951|A/chicken/Coahuila/1433-3/2005|**gb, input date:
#        	[2005.0013698630137, 2005.9986301369863], apparent date: 2007.59
#
# 1116.22	H5N2|KM368305|A/chicken/Durango/1348-06/2006|**gb, input date:
#        	[2006.0863013698631, 2006.1602739726027], apparent date: 2007.90
#
# 1116.22	H5N2|KM368286|A/chicken/Queretaro/0089-06/2006|**gb, input date:
#        	[2006.0013698630137, 2006.0835616438355], apparent date: 2008.52
#
# 1116.22	H5N2|KM455945|A/chicken/Coahuila/1433-15/2006|**gb, input date:
#        	[2006.0013698630137, 2006.9986301369863], apparent date: 2008.52
#
# 1116.22	H5N2|KM368308|A/chicken/Durango/2880-06/2006|**gb, input date:
#        	[2006.16301369863, 2006.2452054794521], apparent date: 2009.02
#
# 1116.22	H5N2|KM368295|A/chicken/Durango/0590-06/2006|**gb, input date:
#        	[2006.9164383561645, 2006.9986301369863], apparent date: 2010.11
#
# 1116.22	H5N2|KM368298|A/chicken/Mexico/876-06/2006|**gb, input date:
#        	[2006.2479452054795, 2006.327397260274], apparent date: 2011.61
#
# 1116.22	H5N2|KM368306|A/chicken/Durango/2238-06/2006|**gb, input date:
#        	[2006.16301369863, 2006.2452054794521], apparent date: 2008.37
#
# 1116.22	H5N2|KM368307|A/chicken/Durango/2393-06/2006|**gb, input date:
#        	[2006.16301369863, 2006.2452054794521], apparent date: 2008.26
#
# 1116.22	H5N2|KM368283|A/chicken/Durango/6973-05/2005|**gb, input date:
#        	[2005.7493150684932, 2005.831506849315], apparent date: 2007.59
#
# 1116.22	H5N2|KM455913|A/chicken/Durango/1433-8/2005|**gb, input date:
#        	[2005.0013698630137, 2005.9986301369863], apparent date: 2008.41
#
# 1116.22	H5N2|KM368290|A/chicken/Mexico/0867-06/2006|**gb, input date:
#        	[2006.2479452054795, 2006.327397260274], apparent date: 2009.62
#
# 1116.22	H5N2|KM368297|A/chicken/Mexico/831-06/2006|**gb, input date:
#        	[2006.2479452054795, 2006.327397260274], apparent date: 2010.61
#
# 1116.22	H5N2|KM368291|A/chicken/Hidalgo/1336-06/2006|**gb, input date:
#        	[2006.2479452054795, 2006.327397260274], apparent date: 2007.19
#
# 1116.22	H5N2|OK205667|A/chicken/Jalisco/LVVX17186-2/2017|**gb, input date:
#        	2017.6424657534246, apparent date: 2017.63
#
# 1116.22	H5N2|MH158232|A/chicken/Guanajuato/CPA-20966-15-VS/2015|**gb, input
#        	date: 2015.4616438356165, apparent date: 2015.63
#
# 1116.22	H5N2|MZ564748|A/chicken/Colima/CPA-04929-17/2017|**gb, input date:
#        	2017.1493150684933, apparent date: 2017.49
#
# 1116.22	H5N2|KM368289|A/chicken/Veracruz/0835-06/2006|**gb, input date:
#        	[2006.0863013698631, 2006.1602739726027], apparent date: 2007.56
#
# 1116.22	H5N2|KM368280|A/chicken/Mexico/6531-05/2005|**gb, input date:
#        	[2005.7493150684932, 2005.831506849315], apparent date: 2008.07
#
# 1116.22	H5N2|KM455897|A/chicken/Mexico/1433-5/2005|**gb, input date:
#        	[2005.0013698630137, 2005.9986301369863], apparent date: 2008.17
#
# 1116.22	H5N2|KM368285|A/chicken/Hidalgo/7637-05/2005|**gb, input date:
#        	[2005.4150684931508, 2005.4945205479453], apparent date: 2008.49
#
# 1116.22	H5N2|KM368302|A/chicken/Michoacan/4240-06/2006|**gb, input date:
#        	[2006.0863013698631, 2006.1602739726027], apparent date: 2009.84
#
# 1116.22	H5N2|KM368296|A/chicken/Chiapas/0681-06/2006|**gb, input date:
#        	[2006.9164383561645, 2006.9986301369863], apparent date: 2009.24
#
# 1116.22	H5N2|KM455929|A/chicken/Durango/1433-10/2006|**gb, input date:
#        	[2006.0013698630137, 2006.9986301369863], apparent date: 2007.79
#
# 1116.22	H5N2|KM455937|A/chicken/Mexico/1433-13/2006|**gb, input date:
#        	[2006.0013698630137, 2006.9986301369863], apparent date: 2007.69
#
# 1116.22	H5N2|KM368288|A/chicken/Mexico/681-06/2006|**gb, input date:
#        	[2006.2479452054795, 2006.327397260274], apparent date: 2008.20
#
# 1116.22	H5N2|KM368287|A/chicken/Mexico/590-06/2006|**gb, input date:
#        	[2006.2479452054795, 2006.327397260274], apparent date: 2008.71
#
# 1116.22	H5N2|OK205523|A/chicken/Coahuila/IA20/2011|**gb, input date:
#        	[2011.0013698630137, 2011.9986301369863], apparent date: 2012.76
#
# 1116.22	H5N2|KM657867|A/chicken/Coahuila/IA05/2009|**gb, input date:
#        	[2009.3301369863013, 2009.4123287671232], apparent date: 2012.65
#
# 1116.22	H5N2|MZ564740|A/chicken/Coahuila/CPA-17850-17/2017|**gb, input date:
#        	2017.4150684931508, apparent date: 2017.70
#
# 1116.22	H5N2|MZ565308|A/chicken/Puebla/CPA-14731-17/2017|**gb, input date:
#        	2017.3383561643836, apparent date: 2018.58
#
# 1116.22	H5N2|MZ564940|A/chicken/Jalisco/CPA-03072-17/2017|**gb, input date:
#        	2017.0890410958905, apparent date: 2020.02
#
# 1116.22	H5N2|MZ564844|A/chicken/Guanajuato/CPA-11248-17/2017|**gb, input date:
#        	2017.2643835616439, apparent date: 2021.03
#
# 1116.22	H5N2|MZ564868|A/chicken/Guanajuato/CPA-17726-17/2017|**gb, input date:
#        	2017.3958904109588, apparent date: 2021.91
#
# 1116.22	H5N2|MZ564908|A/chicken/Hidalgo/CPA-48304-16/2016|**gb, input date:
#        	2016.9275956284152, apparent date: 2021.60
#
# 1116.22	H5N2|MZ565380|A/chicken/Queretaro/CPA-05386-17/2017|**gb, input date:
#        	2017.1493150684933, apparent date: 2021.71
#
# 1116.22	H5N2|MZ564860|A/chicken/Guanajuato/CPA-15050-17/2017|**gb, input date:
#        	2017.341095890411, apparent date: 2022.33
#
# 1116.22	H5N2|MZ564724|A/chicken/Aguascalientes/CPA-20747-17/2017|**gb, input
#        	date: 2017.472602739726, apparent date: 2023.58
#
# 1116.22	H5N2|MZ565276|A/chicken/Morelos/CPA-18659-17/2017|**gb, input date:
#        	2017.4287671232876, apparent date: 2023.58
#
# 1116.22	H5N2|MZ564892|A/chicken/Hidalgo/CPA-03739-17/2017|**gb, input date:
#        	2017.1191780821919, apparent date: 2023.07
#
# 1116.22	H5N2|MZ565492|A/chicken/Yucatan/CPA-15038-17/2017|**gb, input date:
#        	2017.3438356164384, apparent date: 2023.37
#
# 1116.22	H5N2|MZ565372|A/chicken/Queretaro/CPA-04673-1/2019|**gb, input date:
#        	2019.2150684931507, apparent date: 2024.83
#
# 1116.22	H5N2|MZ564796|A/chicken/Guanajuato/CPA-05981-19/2019|**gb, input date:
#        	2019.2671232876712, apparent date: 2025.17
#
# 1116.22	H5N2|MZ564716|A/chicken/Aguascalientes/CPA-08553-19/2019|**gb, input
#        	date: 2019.3821917808218, apparent date: 2025.07
#
# 1116.22	H5N2|MZ564836|A/chicken/Guanajuato/CPA-08992-19/2019|**gb, input date:
#        	2019.4013698630138, apparent date: 2025.27
#
# 1116.22	H5N2|MZ564820|A/chicken/Guanajuato/CPA-08523-19/2019|**gb, input date:
#        	2019.3821917808218, apparent date: 2025.27
#
# 1116.22	H5N2|MZ564828|A/chicken/Guanajuato/CPA-08990-19/2019|**gb, input date:
#        	2019.4013698630138, apparent date: 2025.27
#
# 1116.22	H5N2|MZ564804|A/chicken/Guanajuato/CPA-07267-19/2019|**gb, input date:
#        	2019.3246575342466, apparent date: 2025.48
#
# 1116.22	H5N2|MZ565404|A/chicken/Queretaro/CPA-09543-19/2019|**gb, input date:
#        	2019.4205479452055, apparent date: 2025.48
#
# 1116.22	H5N2|KM368303|A/chicken/Aguascalientes/4244-06/2006|**gb, input date:
#        	[2006.16301369863, 2006.2452054794521], apparent date: 2008.87
#
# 1116.22	H5N2|GU050159|A/yellow-headed_Amazon/California/500658/2007|**gb, input
#        	date: [2007.0013698630137, 2007.9986301369863], apparent date: 2008.41
#
# 1116.22	H5N2|KM657859|A/chicken/Aguascalientes/IA13/2010|**gb, input date:
#        	[2010.2479452054795, 2010.327397260274], apparent date: 2013.65
#
# 1116.22	H5N2|MZ565212|A/chicken/Jalisco/CPA-49745-16/2016|**gb, input date:
#        	2016.9658469945355, apparent date: 2018.50
#
# 1116.22	H5N2|MZ565180|A/chicken/Jalisco/CPA-12377-17/2017|**gb, input date:
#        	2017.2972602739726, apparent date: 2018.24
#
# 1116.22	H5N2|MZ564772|A/chicken/Guanajuato/CPA-00801-17/2017|**gb, input date:
#        	2017.0424657534247, apparent date: 2017.19
#
# 1116.22	H5N2|OK205659|A/chicken/Jalisco/LVVX17144-1/2017|**gb, input date:
#        	2017.6424657534246, apparent date: 2017.19
#
# 1116.22	H5Nx|MF280172|A/chicken/Mexico/P-14/2016|**gb, input date:
#        	2016.4193989071039, apparent date: 2017.29
#
# 1116.22	H5N2|MZ565340|A/chicken/Queretaro/CPA-03805-19/2019|**gb, input date:
#        	2019.1794520547944, apparent date: 2018.13
#
# 1116.22	H5N2|MZ565228|A/chicken/Mexico/CPA-19234-17/2017|**gb, input date:
#        	2017.4479452054795, apparent date: 2018.43
#
# 1116.22	H5N2|MZ565356|A/chicken/Queretaro/CPA-03807-19/2019|**gb, input date:
#        	2019.1794520547944, apparent date: 2018.33
#
# 1116.22	H5N2|MZ565196|A/chicken/Jalisco/CPA-22166-17/2017|**gb, input date:
#        	2017.4917808219177, apparent date: 2018.23
#
# 1116.22	H5N2|MZ564876|A/chicken/Guanajuato/CPA-44870-17/2017|**gb, input date:
#        	2017.9657534246576, apparent date: 2018.85
#
# 1116.22	H5N2|MZ564932|A/chicken/Jalisco/CPA-02169-17/2017|**gb, input date:
#        	2017.0671232876712, apparent date: 2017.81
#
# 1116.22	H5N2|OK205491|A/chicken/Jalisco/716-2/2017|**gb, input date:
#        	2017.5054794520547, apparent date: 2018.12
#
# 1116.22	H5N2|MZ564948|A/chicken/Jalisco/CPA-03198-17/2017|**gb, input date:
#        	2017.0917808219178, apparent date: 2018.02
#
# 1116.22	H5N2|MZ564924|A/chicken/Jalisco/CPA-00823-17/2017|**gb, input date:
#        	2017.0342465753424, apparent date: 2018.23
#
# 1116.22	H5N2|MZ564916|A/chicken/Jalisco/CPA-00822-17/2017|**gb, input date:
#        	2017.0342465753424, apparent date: 2018.12
#
# 1116.22	H5N2|MZ564964|A/chicken/Jalisco/CPA-03518-17/2017|**gb, input date:
#        	2017.1054794520549, apparent date: 2018.43
#
# 1116.22	H5N2|MZ565220|A/chicken/Jalisco/CPA-49950-16/2016|**gb, input date:
#        	2016.9685792349726, apparent date: 2018.33
#
# 1116.22	H5N2|MZ565036|A/chicken/Jalisco/CPA-06116-17/2017|**gb, input date:
#        	2017.16301369863, apparent date: 2018.64
#
# 1116.22	H5N2|MZ564852|A/chicken/Guanajuato/CPA-12461-17/2017|**gb, input date:
#        	2017.2945205479452, apparent date: 2018.96
#
# 1116.22	H5N2|MZ565204|A/chicken/Jalisco/CPA-49007-16/2016|**gb, input date:
#        	2016.9494535519125, apparent date: 2018.75
#
# 1116.22	H5N2|MZ565252|A/chicken/Michoacan/CPA-49737-16/2016|**gb, input date:
#        	2016.9658469945355, apparent date: 2019.35
#
# 1116.22	H5N2|MZ565236|A/chicken/Michoacan/CPA-48911-16/2016|**gb, input date:
#        	2016.9494535519125, apparent date: 2019.46
#
# 1116.22	H5N2|MZ565244|A/chicken/Michoacan/CPA-48912-16/2016|**gb, input date:
#        	2016.9494535519125, apparent date: 2019.56
#
# 1116.23	H5N2|MZ565268|A/chicken/Morelos/CPA-05154-17/2017|**gb, input date:
#        	2017.1465753424657, apparent date: 2019.17
#
# 1116.23	H5N2|MZ565460|A/chicken/Veracruz/CPA-05599-17/2017|**gb, input date:
#        	2017.1657534246576, apparent date: 2019.38
#
# 1116.23	H5N2|MZ565452|A/chicken/Veracruz/CPA-04704-17/2017|**gb, input date:
#        	2017.1438356164383, apparent date: 2019.27
#
# 1116.23	H5N2|MZ565436|A/chicken/Veracruz/CPA-00735-17/2017|**gb, input date:
#        	2017.0342465753424, apparent date: 2018.96
#
# 1116.23	H5N2|MZ565444|A/chicken/Veracruz/CPA-00736-17/2017|**gb, input date:
#        	2017.0342465753424, apparent date: 2019.07
#
# 1116.23	H5N2|MZ565260|A/chicken/Morelos/CPA-02447-17/2017|**gb, input date:
#        	2017.0835616438355, apparent date: 2019.80
#
# 1116.23	H5N2|MZ565316|A/chicken/Queretaro/CPA-02177-17/2017|**gb, input date:
#        	2017.0835616438355, apparent date: 2019.80
#
# 1116.23	H5N2|MZ565388|A/chicken/Queretaro/CPA-06507-17/2017|**gb, input date:
#        	2017.176712328767, apparent date: 2019.80
#
# 1116.23	H5N2|MZ565484|A/chicken/Veracruz/CPA-21377-17/2017|**gb, input date:
#        	2017.4753424657533, apparent date: 2019.91
#
# 1116.23	H5N2|MZ565476|A/chicken/Veracruz/CPA-13920-18/2018|**gb, input date:
#        	2018.4890410958903, apparent date: 2020.85
#
# 1116.23	H5N2|MZ565412|A/chicken/Queretaroa/CPA-11747-18/2018|**gb, input date:
#        	2018.4287671232876, apparent date: 2020.96
#
# 1116.23	H5N2|MZ565076|A/chicken/Jalisco/CPA-06811-19/2019|**gb, input date:
#        	2019.3082191780823, apparent date: 2022.24
#
# 1116.23	H5N2|MZ565172|A/chicken/Jalisco/CPA-09057-19/2019|**gb, input date:
#        	2019.4041095890411, apparent date: 2021.80
#
# 1116.23	H5N2|MZ564900|A/chicken/Hidalgo/CPA-41295-17/2017|**gb, input date:
#        	2017.8780821917808, apparent date: 2021.36
#
# 1116.23	H5N2|MZ564980|A/chicken/Jalisco/CPA-03607-19/2019|**gb, input date:
#        	2019.1739726027397, apparent date: 2021.36
#
# 1116.23	H5N2|MZ564996|A/chicken/Jalisco/CPA-04262-19/2019|**gb, input date:
#        	2019.1986301369864, apparent date: 2021.98
#
# 1116.23	H5N2|MZ564956|A/chicken/Jalisco/CPA-03447-19/2019|**gb, input date:
#        	2019.1602739726027, apparent date: 2022.23
#
# 1116.23	H5N2|MZ565004|A/chicken/Jalisco/CPA-04649-19/2019|**gb, input date:
#        	2019.2150684931507, apparent date: 2022.34
#
# 1116.23	H5N2|MZ565156|A/chicken/Jalisco/CPA-08826-19/2019|**gb, input date:
#        	2019.390410958904, apparent date: 2023.07
#
# 1116.23	H5N2|MZ565028|A/chicken/Jalisco/CPA-06016-19/2019|**gb, input date:
#        	2019.2698630136986, apparent date: 2022.65
#
# 1116.23	H5N2|MZ565108|A/chicken/Jalisco/CPA-07541-19/2019|**gb, input date:
#        	2019.3328767123287, apparent date: 2022.44
#
# 1116.23	H5N2|MZ565164|A/chicken/Jalisco/CPA-08831-19/2019|**gb, input date:
#        	2019.390410958904, apparent date: 2022.44
#
# 1116.23	H5N2|MZ565012|A/chicken/Jalisco/CPA-04758-19/2019|**gb, input date:
#        	2019.217808219178, apparent date: 2022.65
#
# 1116.23	H5N2|MZ565020|A/chicken/Jalisco/CPA-05091-19/2019|**gb, input date:
#        	2019.231506849315, apparent date: 2022.44
#
# 1116.23	H5N2|MZ565044|A/chicken/Jalisco/CPA-06432-19/2019|**gb, input date:
#        	2019.286301369863, apparent date: 2022.54
#
# 1116.23	H5N2|MZ564988|A/chicken/Jalisco/CPA-04141-19/2019|**gb, input date:
#        	2019.195890410959, apparent date: 2022.54
#
# 1116.23	H5N2|MZ565148|A/chicken/Jalisco/CPA-08244-19/2019|**gb, input date:
#        	2019.3657534246574, apparent date: 2022.54
#
# 1116.23	H5N2|MZ565068|A/chicken/Jalisco/CPA-06799-19/2019|**gb, input date:
#        	2019.3082191780823, apparent date: 2022.44
#
# 1116.23	H5N2|MZ565116|A/chicken/Jalisco/CPA-07715-19/2019|**gb, input date:
#        	2019.3465753424657, apparent date: 2022.86
#
# 1116.23	H5N2|MZ565140|A/chicken/Jalisco/CPA-08103-19/2019|**gb, input date:
#        	2019.36301369863, apparent date: 2023.06
#
# 1116.23	H5N2|MZ565292|A/chicken/Puebla/CPA-03924-19/2019|**gb, input date:
#        	2019.190410958904, apparent date: 2021.13
#
# 1116.23	H5N2|MZ564700|A/chicken/Aguascalientes/CPA-08115-19/2019|**gb, input
#        	date: 2019.36301369863, apparent date: 2021.76
#
# 1116.23	H5N2|MZ564708|A/chicken/Aguascalientes/CPA-08545-19/2019|**gb, input
#        	date: 2019.3821917808218, apparent date: 2022.17
#
# 1116.23	H5N2|MZ565188|A/chicken/Jalisco/CPA-16963-18/2018|**gb, input date:
#        	2018.5794520547945, apparent date: 2021.57
#
# 1116.23	H5N2|MZ565284|A/chicken/Puebla/CPA-01572-18/2018|**gb, input date:
#        	2018.0753424657535, apparent date: 2020.64
#
# 1116.23	H5N2|MZ564692|A/chicken/Aguascalientes/CPA-07181-19/2019|**gb, input
#        	date: 2019.3246575342466, apparent date: 2021.80
#
# 1116.23	H5N2|MZ565100|A/chicken/Jalisco/CPA-07195-19/2019|**gb, input date:
#        	2019.3246575342466, apparent date: 2022.10
#
# 1116.23	H5N2|OK205699|A/chicken/Mexico/1864/2019|**gb, input date:
#        	2019.672602739726, apparent date: 2022.41
#
# 1116.23	H5N2|MZ565052|A/chicken/Jalisco/CPA-06504-19/2019|**gb, input date:
#        	2019.286301369863, apparent date: 2021.68
#
# 1116.23	H5N2|MZ565060|A/chicken/Jalisco/CPA-06506-19/2019|**gb, input date:
#        	2019.286301369863, apparent date: 2021.57
#
# 1116.23	H5N2|MZ564788|A/chicken/Guanajuato/CPA-04382-19/2019|**gb, input date:
#        	2019.2013698630137, apparent date: 2022.09
#
# 1116.23	H5N2|MZ565364|A/chicken/Queretaro/CPA-04112-19/2019|**gb, input date:
#        	2019.1931506849314, apparent date: 2021.89
#
# 1116.23	H5N2|MZ564732|A/chicken/Aguascallientes/CPA-08331-19/2019|**gb, input
#        	date: 2019.368493150685, apparent date: 2022.20
#
# 1116.23	H5N2|MZ564780|A/chicken/Guanajuato/CPA-03879-19/2019|**gb, input date:
#        	2019.182191780822, apparent date: 2022.09
#
# 1116.23	H5N2|OK205683|A/chicken/Mexico/1643/2019|**gb, input date:
#        	2019.3657534246574, apparent date: 2022.42
#
# 1116.23	H5N2|MZ565396|A/chicken/Queretaro/CPA-09515-19/2019|**gb, input date:
#        	2019.4205479452055, apparent date: 2022.94
#
# 1116.23	H5N2|MZ565300|A/chicken/Puebla/CPA-06927-19/2019|**gb, input date:
#        	2019.3109589041096, apparent date: 2022.40
#
# 1116.23	H5N2|MZ565428|A/chicken/San_Luis_Potosi/CPA-05890-19/2019|**gb, input
#        	date: 2019.2671232876712, apparent date: 2022.52
#
# 1116.23	H5N2|MZ565092|A/chicken/Jalisco/CPA-07140-19/2019|**gb, input date:
#        	2019.3164383561643, apparent date: 2022.72
#
# 1116.23	H5N2|MZ565420|A/chicken/San_Luis_Potosi/CPA-05885-19/2019|**gb, input
#        	date: 2019.2671232876712, apparent date: 2022.83
#
# 1116.23	H5N2|MZ565084|A/chicken/Jalisco/CPA-07139-19/2019|**gb, input date:
#        	2019.3164383561643, apparent date: 2022.93
#
# 1116.23	H5N2|MZ564684|A/chicken/Aguascalientes/CPA-07048-19/2019|**gb, input
#        	date: 2019.313698630137, apparent date: 2022.40
#
# 1116.23	H5N2|MZ564676|A/chicken/Aguascalientes/CPA-04479-19/2019|**gb, input
#        	date: 2019.2123287671234, apparent date: 2022.09
#
# 1116.23	H5N2|MZ564652|A/chicken/Aguascalientes/CPA-03202-19/2019|**gb, input
#        	date: 2019.1520547945206, apparent date: 2021.99
#
# 1116.23	H5N2|MZ565132|A/chicken/Jalisco/CPA-07737-19/2019|**gb, input date:
#        	2019.3465753424657, apparent date: 2021.99
#
# 1116.23	H5N2|MZ564660|A/chicken/Aguascalientes/CPA-03203-19/2019|**gb, input
#        	date: 2019.1520547945206, apparent date: 2021.99
#
# 1116.23	H5N2|OK205691|A/chicken/Mexico/1863/2019|**gb, input date:
#        	2019.672602739726, apparent date: 2022.20
#
# 1116.23	H5N2|MZ565124|A/chicken/Jalisco/CPA-07736-19/2019|**gb, input date:
#        	2019.3465753424657, apparent date: 2021.99
#
# 1116.23	H5N2|CY206260|A/mallard/Minnesota/AI12-4031/2012|**gb, input date:
#        	2012.7199453551912, apparent date: 2011.58
#
# 1116.23	H5N2|MH546603|A/mallard/Maryland/16-042534-2/2016|**gb, input date:
#        	2016.9877049180327, apparent date: 2015.88
#
# 1116.23	H5N2|MN430989|A/American_Green-winged_Teal/Ohio/18OS01681/2018|**gb,
#        	input date: 2018.6671232876713, apparent date: 2017.78
#
# 1116.23	H5N2|MH546611|A/mallard/Michigan/15-031493-1/2015|**gb, input date:
#        	2015.7493150684932, apparent date: 2014.71
#
# 1116.23	H5N2|KY561037|A/northern_pintail/Ohio/15OS5861/2015|**gb, input date:
#        	2015.8698630136987, apparent date: 2015.38
#
# 1116.23	H5N6|MH546731|A/mallard/Pennsylvania/16-035727-1/2016|**gb, input date:
#        	2016.700819672131, apparent date: 2015.79
#
# 1116.23	H5N2|MH546523|A/lesser_snow_goose/Arkansas/16-005566-3/2016|**gb, input
#        	date: 2016.1079234972678, apparent date: 2015.68
#
# 1116.23	H5N5|MH546667|A/mallard/Minnesota/16-041335-4/2016|**gb, input date:
#        	2016.7226775956285, apparent date: 2015.71
#
# 1116.23	H5N2|MH547019|A/turkey/Wisconsin/17-007319-3/2017|**gb, input date:
#        	2017.168493150685, apparent date: 2016.06
#
# 1116.23	H5N2|MH547003|A/turkey/Wisconsin/17-007146-1/2017|**gb, input date:
#        	2017.1657534246576, apparent date: 2016.37
#
# 1116.23	H5N2|MH547011|A/turkey/Wisconsin/17-007146-2/2017|**gb, input date:
#        	2017.1657534246576, apparent date: 2016.45
#
# 1116.23	H5N2|MH546659|A/mallard/Minnesota/16-041335-3/2016|**gb, input date:
#        	2016.7226775956285, apparent date: 2016.56
#
# 1116.23	H5N1|MH546699|A/mallard/North_Dakota/16-036222-1/2016|**gb, input date:
#        	2016.818306010929, apparent date: 2015.95
#
# 1116.23	H5N2|MW132176|A/mallard/California/SL06B72H5/2018|**gb, input date:
#        	2018.7849315068493, apparent date: 2010.93
#
# 1116.23	H5N2|KY130664|A/glaucous-winged_gull/Alaska/392/2011|**gb, input date:
#        	2011.7191780821918, apparent date: 2010.97
#
# 1116.23	H5N2|CY133909|A/northern_shoveler/California/2815/2011|**gb, input date:
#        	2011.8260273972603, apparent date: 2010.87
#
# 1116.23	H5N2|KY130859|A/northern_pintail/Alaska/622/2012|**gb, input date:
#        	2012.7418032786886, apparent date: 2011.28
#
# 1116.23	H5N2|CY166776|A/northern_shoveler/Mississippi/11OS5875/2011|**gb, input
#        	date: 2011.9356164383562, apparent date: 2010.47
#
# 1116.23	H5N2|CY133153|A/American_green-winged_teal/Wisconsin/10OS3127/2010|**gb,
#        	input date: 2010.8013698630136, apparent date: 2010.21
#
# 1116.23	H5N2|KX351587|A/American_wigeon/California/LS257/2014|**gb, input date:
#        	2014.968493150685, apparent date: 2011.26
#
# 1116.23	H5N2|MH546227|A/American_wigeon/Colorado/15-038180-1/2015|**gb, input
#        	date: 2015.8890410958904, apparent date: 2011.77
#
# 1116.23	H5N2|MH546219|A/American_wigeon/California/15-039075-7/2015|**gb, input
#        	date: 2015.9191780821918, apparent date: 2011.67
#
# 1116.23	H5N2|MH546243|A/American_wigeon/Utah/15-038912-1/2015|**gb, input date:
#        	2015.886301369863, apparent date: 2012.00
#
# 1116.23	H5N2|CY213604|A/least_sandpiper/Southcentral_Alaska/16MB01323/2016|**gb,
#        	input date: 2016.3592896174864, apparent date: 2013.57
#
# 1116.23	H5N2|CY213568|A/sandpiper/Southcentral_Alaska/16MB01156/2016|**gb, input
#        	date: 2016.3483606557377, apparent date: 2013.57
#
# 1116.23	H5N2|CY213612|A/least_sandpiper/Southcentral_Alaska/16MB01324/2016|**gb,
#        	input date: 2016.3592896174864, apparent date: 2014.09
#
# 1116.23	H5N2|CY213576|A/sandpiper/Southcentral_Alaska/16MB01220/2016|**gb, input
#        	date: 2016.3483606557377, apparent date: 2013.36
#
# 1116.23	H5N2|CY213518|A/glaucous-
#        	winged_gull/Southcentral_Alaska/16AS00020/2016|**gb, input date:
#        	2016.1707650273224, apparent date: 2013.57
#
# 1116.23	H5N2|CY213584|A/sandpiper/Southcentral_Alaska/16MB01259/2016|**gb, input
#        	date: 2016.353825136612, apparent date: 2013.46
#
# 1116.23	H5N3|KT338321|A/mallard/Alaska/103/2014|**gb, input date:
#        	2014.7054794520548, apparent date: 2012.99
#
# 1116.23	H5Nx|MK326768|A/blue-winged_teal/Guatemala/CIP049-H116-26/2013|**gb,
#        	input date: [2013.0013698630137, 2013.9986301369863], apparent date:
#        	2012.25
#
# 1116.23	H5N2|MK326648|A/blue-winged_teal/Guatemala/CIP049-H116-96/2013|**gb,
#        	input date: [2013.0013698630137, 2013.9986301369863], apparent date:
#        	2012.55
#
# 1116.23	H5N5|CY177329|A/mallard/California/1435/2013|**gb, input date:
#        	2013.5602739726028, apparent date: 2011.44
#
# 1116.23	H5N5|CY177199|A/mallard/California/1375/2013|**gb, input date:
#        	2013.554794520548, apparent date: 2011.44
#
# 1116.23	H5N5|CY177231|A/mallard/California/1395/2013|**gb, input date:
#        	2013.5575342465754, apparent date: 2011.44
#
# 1116.23	H5N5|CY176965|A/mallard/California/1402/2013|**gb, input date:
#        	2013.5575342465754, apparent date: 2011.44
#
# 1116.23	H5N5|CY177183|A/mallard/California/1370/2013|**gb, input date:
#        	2013.554794520548, apparent date: 2011.65
#
# 1116.23	H5N5|CY177149|A/mallard/California/1357/2013|**gb, input date:
#        	2013.554794520548, apparent date: 2011.75
#
# 1116.23	H5N5|CY177191|A/mallard/California/1371/2013|**gb, input date:
#        	2013.554794520548, apparent date: 2011.44
#
# 1116.23	H5N5|CY177207|A/mallard/California/1376/2013|**gb, input date:
#        	2013.554794520548, apparent date: 2011.65
#
# 1116.23	H5N5|CY177297|A/mallard/California/1413/2013|**gb, input date:
#        	2013.5575342465754, apparent date: 2011.65
#
# 1116.23	H5N5|CY177345|A/mallard/California/1480/2013|**gb, input date:
#        	2013.5767123287671, apparent date: 2011.75
#
# 1116.23	H5N5|CY177401|A/mallard/California/1496/2013|**gb, input date:
#        	2013.5767123287671, apparent date: 2011.85
#
# 1116.23	H5N6|CY176973|A/mallard/California/1418/2013|**gb, input date:
#        	2013.5575342465754, apparent date: 2011.85
#
# 1116.23	H5N5|CY177417|A/mallard/California/1499/2013|**gb, input date:
#        	2013.5767123287671, apparent date: 2012.06
#
# 1116.23	H5N5|CY177385|A/mallard/California/1490/2013|**gb, input date:
#        	2013.5767123287671, apparent date: 2011.95
#
# 1116.23	H5N5|CY177279|A/mallard/California/1411/2013|**gb, input date:
#        	2013.5575342465754, apparent date: 2011.65
#
# 1116.23	H5N5|CY177109|A/mallard/California/942V/2013|**gb, input date:
#        	2013.5821917808219, apparent date: 2011.75
#
# 1116.23	H5N6|CY177425|A/mallard/California/1500P/2013|**gb, input date:
#        	2013.5767123287671, apparent date: 2011.75
#
# 1116.23	H5N5|CY177393|A/mallard/California/1495/2013|**gb, input date:
#        	2013.5767123287671, apparent date: 2011.65
#
# 1116.23	H5N5|CY177433|A/mallard/California/1500V/2013|**gb, input date:
#        	2013.5767123287671, apparent date: 2011.65
#
# 1116.23	H5N5|CY177313|A/mallard/California/1433/2013|**gb, input date:
#        	2013.5602739726028, apparent date: 2011.65
#
# 1116.23	H5N5|CY177337|A/mallard/California/1478/2013|**gb, input date:
#        	2013.5767123287671, apparent date: 2011.75
#
# 1116.23	H5N5|CY177353|A/mallard/California/1481/2013|**gb, input date:
#        	2013.5767123287671, apparent date: 2011.75
#
# 1116.23	H5N5|CY177215|A/mallard/California/1386/2013|**gb, input date:
#        	2013.5575342465754, apparent date: 2011.55
#
# 1116.23	H5N5|CY177263|A/mallard/California/1399/2013|**gb, input date:
#        	2013.5575342465754, apparent date: 2011.65
#
# 1116.23	H5N5|CY177305|A/mallard/California/1426/2013|**gb, input date:
#        	2013.5575342465754, apparent date: 2011.65
#
# 1116.23	H5N5|CY177321|A/mallard/California/1434/2013|**gb, input date:
#        	2013.5602739726028, apparent date: 2011.65
#
# 1116.23	H5N5|CY177247|A/mallard/California/1397/2013|**gb, input date:
#        	2013.5575342465754, apparent date: 2011.75
#
# 1116.23	H5N5|CY177069|A/mallard/California/928V/2013|**gb, input date:
#        	2013.5821917808219, apparent date: 2011.75
#
# 1116.23	H5N2|KX351551|A/American_wigeon/California/COL041/2014|**gb, input date:
#        	2014.795890410959, apparent date: 2011.77
#
# 1116.23	H5N1|MG279989|A/black_duck/Tennessee/17OS0306/2017|**gb, input date:
#        	2017.0342465753424, apparent date: 2012.18
#
# 1116.23	H5N1|MG280333|A/gadwall_duck/Tennessee/17OS0341/2017|**gb, input date:
#        	2017.0369863013698, apparent date: 2012.29
#
# 1116.23	H5N2|MK828142|A/Mexican_duck/EstadodeMexico-
#        	_Lerma/HA_UIFMVZ377/2016|**gb, input date: 2016.9439890710382, apparent
#        	date: 2012.91
#
# 1116.23	H5N2|KY284403|A/gadwall/Arkansas/15OS7729/2015|**gb, input date:
#        	2015.9630136986302, apparent date: 2012.50
#
# 1116.23	H5N2|MH546707|A/mallard/Oregon/15-036812-2/2015|**gb, input date:
#        	2015.8534246575343, apparent date: 2011.67
#
# 1116.23	H5N1|MH546331|A/blue-winged_teal/Texas/16-031241-1/2016|**gb, input
#        	date: 2016.7117486338798, apparent date: 2012.48
#
# 1116.23	H5N8|MK345909|A/laughing_gull/Delaware_Bay/486/2018|**gb, input date:
#        	2018.390410958904, apparent date: 2014.46
#
# 1116.23	H5N9|CY235315|A/mallard/Idaho/UGAI16-1964/2016|**gb, input date:
#        	2016.629781420765, apparent date: 2012.38
#
# 1116.23	H5N9|MH546187|A/American_green-winged_teal/Idaho/16-028809-8/2016|**gb,
#        	input date: 2016.6434426229507, apparent date: 2012.18
#
# 1116.23	H5N9|MH546179|A/American_green-winged_teal/Idaho/16-028809-5/2016|**gb,
#        	input date: 2016.6434426229507, apparent date: 2012.08
#
# 1116.23	H5N9|MH546195|A/American_green-winged_teal/Idaho/16-028809-9/2016|**gb,
#        	input date: 2016.6434426229507, apparent date: 2012.08
#
# 1116.23	H5N9|MH546755|A/mallard/Utah/16-025311-2/2016|**gb, input date:
#        	2016.577868852459, apparent date: 2012.18
#
# 1116.23	H5N2|MH546971|A/ring-necked_duck/California/16-004032-1/2016|**gb, input
#        	date: 2016.0833333333333, apparent date: 2012.48
#
# 1116.23	H5N2|MH546141|A/mallard/Alaska/16-029597-2/2016|**gb, input date:
#        	2016.6762295081967, apparent date: 2012.69
#
# 1116.23	H5N2|MH546723|A/mallard/Oregon/17-000383-4/2016|**gb, input date:
#        	2016.99043715847, apparent date: 2012.69
#
# 1116.23	H5N2|MH546211|A/American_green-winged_teal/Oregon/17-000383-3/2016|**gb,
#        	input date: 2016.99043715847, apparent date: 2012.58
#
# 1116.23	H5N2|MH546235|A/American_wigeon/Oregon/17-000383-2/2016|**gb, input
#        	date: 2016.99043715847, apparent date: 2012.58
#
# 1116.23	H5N2|MK995858|A/Northern_Shoveler/Utah/D1715326/2017|**gb, input date:
#        	2017.8698630136987, apparent date: 2013.41
#
# 1116.23	H5N2|MK995866|A/Ring-necked_Duck/Arizona/D1715902/2017|**gb, input date:
#        	2017.9082191780822, apparent date: 2013.41
#
# 1116.23	H5N2|MN431106|A/Mallard/Illinois/17OS2751/2017|**gb, input date:
#        	2017.8643835616438, apparent date: 2013.31
#
# 1116.23	H5N2|MT566447|A/Mallard/Ohio/18OS2631/2018|**gb, input date:
#        	[2018.0013698630137, 2018.9986301369863], apparent date: 2013.30
#
# 1116.23	H5N2|MN431009|A/Mallard/Ohio/18OS1892/2018|**gb, input date:
#        	2018.7931506849316, apparent date: 2013.61
#
# 1116.23	H5N2|MN795001|A/northern_pintail/Ohio/18OS1936/2018|**gb, input date:
#        	2018.809589041096, apparent date: 2013.92
#
# 1116.23	H5N2|ON366874|A/Sanderling/Delaware/518/2021|**gb, input date:
#        	2021.4150684931508, apparent date: 2015.09
#
# 1116.23	H5N2|OL514206|A/mallard/Vermont/AH0188123/2021|**gb, input date:
#        	2021.6698630136987, apparent date: 2014.78
#
# 1116.23	H5N4|OL422862|A/mallard/New_York/AH0179244/2021|**gb, input date:
#        	2021.609589041096, apparent date: 2014.88
#
# ...
#        	2015.7054794520548, apparent date: 2011.29
#
# 1116.26	H5N6|MF693964|A/mallard_duck/Netherlands/52/2015|**gb, input date:
#        	2015.7082191780821, apparent date: 2011.29
#
# 1116.26	H5N3|MT407097|A/Anas_platyrhynchos/Belgium/9074_H191808/2016|**gb, input
#        	date: 2016.733606557377, apparent date: 2010.96
#
# 1116.26	H5N3|MT406841|A/Anas_platyrhynchos/Belgium/10749_47/2017|**gb, input
#        	date: 2017.6424657534246, apparent date: 2011.77
#
# 1116.26	H5N3|EPI1841825|A/swan/Netherlands/18019125-002/2018|, input date:
#        	2018.990410958904, apparent date: 2012.70
#
# 1116.26	H5N3|EPI1841833|A/duck/Netherlands/18018989-011015/2018|, input date:
#        	2018.9794520547946, apparent date: 2012.60
#
# 1116.26	H5N3|MT407081|A/Anas_platyrhynchos/Belgium/8862_H170636/2016|**gb, input
#        	date: 2016.7199453551912, apparent date: 2011.16
#
# 1116.26	H5N3|MT407113|A/Anas_platyrhynchos/Belgium/9473/2016|**gb, input date:
#        	2016.7581967213114, apparent date: 2011.06
#
# 1116.26	H5N2|EPI1942394|A/Anas_platyrhynchos/Belgium/10413_0003/2020|, input
#        	date: 2020.7581967213114, apparent date: 2013.23
#
# 1116.26	H5N2|EPI1882954|A_mallard_Denmark_12946-11_2020-10-26|, input date:
#        	2020.818306010929, apparent date: 2012.38
#
# 1116.26	H5N6|MT406809|A/Anas_Platyrhynchos/Belgium/10811_6/2019|**gb, input
#        	date: 2019.7219178082191, apparent date: 2012.11
#
# 1116.26	H5N2|EPI1963336|A/Mallard/Netherlands/11/2021|, input date:
#        	2021.9657534246576, apparent date: 2013.75
#
# 1116.26	H5N2|EPI2197849|A/Mallard/Netherlands/17/2022|, input date:
#        	2022.7493150684932, apparent date: 2014.14
#
# 1116.26	H5N2|EPI1966938|A/Mallard/Netherlands/16/2021|, input date:
#        	2021.9767123287672, apparent date: 2013.31
#
# 1116.26	H5N3|KF501050|A/wild_bird/Mongolia/2066/2011|**gb, input date:
#        	2011.768493150685, apparent date: 2009.49
#
# 1116.26	H5N3|KF501076|A/common_shelduck/Mongolia/2187/2011|**gb, input date:
#        	2011.7712328767122, apparent date: 2009.49
#
# 1116.26	H5N3|EPI884247|A/mallard/Chany/260U/2014|, input date:
#        	2014.6917808219177, apparent date: 2010.92
#
# 1116.26	H5N3|EPI884255|A/mallard/Chany/126K/2014|, input date:
#        	2014.694520547945, apparent date: 2010.60
#
# 1116.26	H5N2|OP905483|A/aquatic_bird/South_Korea/CN73/2014|**gb, input date:
#        	2014.9027397260274, apparent date: 2010.08
#
# 1116.26	H5N3|MN171442|A/duck/Jiangsu/S1665/2015|**gb, input date:
#        	2015.2506849315068, apparent date: 2010.49
#
# 1116.26	H5N3|EPI855964|A/duck/Kagoshima/46-04/2014|, input date:
#        	[2014.9164383561645, 2014.9986301369863], apparent date: 2010.18
#
# 1116.26	H5N3|OP905461|A/aquatic_bird/South_Korea/CN60/2014|**gb, input date:
#        	2014.9027397260274, apparent date: 2009.97
#
# 1116.26	H5N3|OP905494|A/aquatic_bird/South_Korea/CN80/2014|**gb, input date:
#        	2014.9027397260274, apparent date: 2010.07
#
# 1116.26	H5N3|OP905492|A/aquatic_bird/South_Korea/CN79/2014|**gb, input date:
#        	2014.9027397260274, apparent date: 2009.97
#
# 1116.26	H5N3|OP905502|A/aquatic_bird/South_Korea/CN84/2014|**gb, input date:
#        	2014.9027397260274, apparent date: 2009.97
#
# 1116.26	H5N3|LC617425|A/duck/Tottori/K191/2015|**gb, input date:
#        	2015.1465753424657, apparent date: 2010.38
#
# 1116.26	H5N6|LC617417|A/duck/Tottori/Vac-T1/2020|**gb, input date:
#        	2020.405737704918, apparent date: 2010.07
#
# 1116.26	H5N8|LC701527|A/duck/Tottori/Vac-T2/2021|**gb, input date:
#        	2021.7465753424658, apparent date: 2009.97
#
# 1116.26	H5N7|LC011482|A/duck/Mongolia/211/2014|**gb, input date:
#        	2014.664383561644, apparent date: 2009.87
#
# 1116.26	H5N7|LC011447|A/duck/Mongolia/107/2014|**gb, input date:
#        	2014.664383561644, apparent date: 2009.77
#
# 1116.26	H5N2|LC011483|A/duck/Mongolia/256/2014|**gb, input date:
#        	2014.664383561644, apparent date: 2009.87
#
# 1116.26	H5N3|EPI1513818|A/white-fronted_goose/Korea/H3334/2015|, input date:
#        	2015.8945205479451, apparent date: 2010.90
#
# 1116.26	H5N3|EPI1513810|A/white-fronted_goose/Korea/H3173/2015|, input date:
#        	2015.8260273972603, apparent date: 2011.00
#
# 1116.26	H5N3|EPI1513826|A/pink-footed_goose/Korea/H3473/2015|, input date:
#        	2015.9712328767123, apparent date: 2011.51
#
# 1116.26	H5N3|EPI855719|A/duck/Yamaguchi/351211/2015|, input date:
#        	[2015.9164383561645, 2015.9986301369863], apparent date: 2011.61
#
# 1116.26	H5N3|EPI1513778|A/broiler_duck/Korea/H3422/2015|, input date:
#        	2015.9602739726026, apparent date: 2011.20
#
# 1116.26	H5N3|MN171434|A/duck/Guangxi/S10712/2018|**gb, input date:
#        	2018.176712328767, apparent date: 2012.44
#
# 1116.26	H5N2|MW126807|A/duck/Hokkaido/W44/2018|**gb, input date:
#        	2018.7986301369863, apparent date: 2012.54
#
# 1116.26	H5N3|EPI855925|A/duck/Tokushima/361002/2015|, input date:
#        	[2015.7493150684932, 2015.831506849315], apparent date: 2011.30
#
# 1116.26	H5N3|EPI1513898|A/spot-billed_duck/Korea/H604-1/2016|, input date:
#        	2016.9877049180327, apparent date: 2012.23
#
# 1116.26	H5N3|MK592461|A/duck/Akita/51019/2017|**gb, input date:
#        	2017.8205479452056, apparent date: 2012.75
#
# 1116.26	H5N3|EPI1513802|A/spot-billed_duck/Korea/H3135/2015|, input date:
#        	2015.83698630137, apparent date: 2011.10
#
# 1116.26	H5N3|EPI1513874|A/bean_goose/Korea/H3316/2015|, input date:
#        	2015.8753424657534, apparent date: 2011.00
#
# 1116.26	H5N3|MG386197|A/aquatic_bird/South_Korea/sw007/2015|**gb, input date:
#        	2015.845205479452, apparent date: 2011.10
#
# 1116.26	H5N8|EPI740809|A/Bean_Goose/Hubei/chenhu__XVI311-2_/2016_H5N8|, input
#        	date: 2016.1543715846994, apparent date: 2011.61
#
# 1116.26	H5N3|EPI873440|A/duck/Ibaraki/22/2016|, input date: 2016.9521857923498,
#        	apparent date: 2012.33
#
# 1116.26	H5N3|EPI1513890|A/spot-billed_duck/Korea/H422-7/2016|, input date:
#        	2016.9521857923498, apparent date: 2011.61
#
# 1116.26	H5N3|EPI1513906|A/white-fronted_goose/Korea/H886/2017|, input date:
#        	2017.0424657534247, apparent date: 2011.81
#
# 1116.26	H5N3|EPI1513914|A/mallard/Korea/H1029-2/2017|, input date:
#        	2017.195890410959, apparent date: 2011.91
#
# 1116.26	H5N3|EPI1513882|A/mandarin_duck/Korea/A44-1-3/2016|, input date:
#        	2016.8428961748634, apparent date: 2011.61
#
# 1116.26	H5N3|EPI1513834|A/mallard/Korea/H50-4/2016|, input date:
#        	2016.8920765027322, apparent date: 2011.81
#
# 1116.26	H5N3|EPI1513850|A/white-fronted_goose/Korea/H96-1/2016|, input date:
#        	2016.9112021857923, apparent date: 2011.71
#
# 1116.26	H5N3|EPI1513858|A/mallard/Korea/H125-4/2016|, input date:
#        	2016.9166666666667, apparent date: 2011.61
#
# 1116.26	H5N3|EPI1513842|A/mallard/Korea/H95-4/2016|, input date:
#        	2016.9112021857923, apparent date: 2011.71
#
# 1116.26	H5N3|OP905553|A/goose/South_Korea/JB18/2016|**gb, input date:
#        	2016.954918032787, apparent date: 2011.81
#
# 1116.26	H5N3|OP905551|A/goose/South_Korea/JB17/2016|**gb, input date:
#        	2016.954918032787, apparent date: 2011.71
#
# 1116.26	H5N3|OP905554|A/goose/South_Korea/JB19/2016|**gb, input date:
#        	2016.954918032787, apparent date: 2011.81
#
# 1116.26	H5N3|MN171426|A/duck/Chongqing/S4362/2017|**gb, input date:
#        	2017.8945205479451, apparent date: 2012.43
#
# 1116.26	H5N3|EPI1514066|A/spot-billed_duck/Korea/A09-1-2/2017|, input date:
#        	2017.7739726027398, apparent date: 2012.53
#
# 1116.26	H5N3|EPI1513930|A/mallard/Korea/A11-4/2017|, input date:
#        	2017.7739726027398, apparent date: 2012.52
#
# 1116.26	H5N3|EPI1513938|A/mallard/Korea/A14-2/2017|, input date:
#        	2017.7739726027398, apparent date: 2012.42
#
# 1116.26	H5N3|MN171466|A/wild_bird/Eastern_China/1758/2017|**gb, input date:
#        	2017.8506849315067, apparent date: 2013.05
#
# 1116.26	H5N3|MN171458|A/wild_bird/Eastern_China/1754/2017|**gb, input date:
#        	2017.8506849315067, apparent date: 2012.94
#
# 1116.26	H5N3|MN171474|A/wild_bird/Eastern_China/1759/2017|**gb, input date:
#        	2017.8506849315067, apparent date: 2012.83
#
# 1116.26	H5N3|MW935859|A/duck/Vietnam/HN5074/2018|**gb, input date:
#        	2018.845205479452, apparent date: 2012.73
#
# 1116.26	H5N3|MW935996|A/duck/Vietnam/HN5076/2018|**gb, input date:
#        	2018.845205479452, apparent date: 2012.73
#
# 1116.26	H5N2|MT477769|A/Wild_duck/South_Korea/KNU18-28/2018|**gb, input date:
#        	2018.7904109589042, apparent date: 2012.32
#
# 1116.26	H5N2|MT477793|A/Bean_Goose/South_Korea/KNU18-86/2018|**gb, input date:
#        	2018.9191780821918, apparent date: 2012.42
#
# 1116.26	H5N2|MT477801|A/Wild_duck/South_Korea/KNU18-93/2018|**gb, input date:
#        	2018.9191780821918, apparent date: 2012.42
#
# 1116.26	H5N3|MN171450|A/duck/Jiangsu/SE0261/2018|**gb, input date:
#        	2018.0232876712328, apparent date: 2012.52
#
# 1116.26	H5N2|EPI1514050|A/bean_goose/Korea/H112/2017|, input date:
#        	2017.9876712328767, apparent date: 2012.52
#
# 1116.26	H5N2|EPI1513962|A/mallard/Korea/H15-1/2017|, input date:
#        	2017.8917808219178, apparent date: 2012.42
#
# 1116.26	H5N3|EPI1514074|A/spot-billed_duck/Korea/H10-1/2017|, input date:
#        	2017.886301369863, apparent date: 2012.32
#
# 1116.26	H5N2|EPI1513946|A/mallard/Korea/A33-5/2017|, input date:
#        	2017.8479452054794, apparent date: 2012.22
#
# 1116.26	H5N3|EPI1513954|A/mallard/Korea/A44-5/2017|, input date:
#        	2017.872602739726, apparent date: 2012.11
#
# 1116.26	H5N3|EPI1657115|A/Spot-billed_Duck/Russia_Primorje/226/2019|, input
#        	date: 2019.8013698630136, apparent date: 2014.30
#
# 1116.26	H5N3|MN493052|A/wild_duck/South_Korea/KNU18-91/2018|**gb, input date:
#        	2018.1164383561643, apparent date: 2013.04
#
# 1116.26	H5N1|MW375479|A/Mallard-
#        	Anas_platyrhynchos-/South_Korea/KNU2019-20/2019|**gb, input date:
#        	2019.168493150685, apparent date: 2012.84
#
# 1116.26	H5N2|EPI1884450|A/whooper_swan/Henan/T880/2018|, input date:
#        	2018.941095890411, apparent date: 2012.73
#
# 1116.26	H5N2|EPI1884510|A/whooper_swan/Henan/Y126/2018|, input date:
#        	2018.982191780822, apparent date: 2012.73
#
# 1116.26	H5N3|MT020182|A/duck/Mongolia/419/2019|**gb, input date:
#        	2019.6972602739727, apparent date: 2013.65
#
# 1116.26	H5N3|MT020150|A/duck/Mongolia/926/2019|**gb, input date:
#        	2019.7191780821918, apparent date: 2013.34
#
# 1116.26	H5N3|MW404512|A/Mallard-
#        	Anas_platyrhynchos-/South_Korea/KNU2019-58/2019|**gb, input date:
#        	2019.823287671233, apparent date: 2013.65
#
# 1116.26	H5N3|MW386777|A/Mallard-
#        	Anas_platyrhynchos-/South_Korea/KNU2019-54/2019|**gb, input date:
#        	2019.809589041096, apparent date: 2013.55
#
# 1116.26	H5N3|EPI2113371|A/Goose/Korea/H277/2022|, input date:
#        	2022.2013698630137, apparent date: 2014.69
#
# 1116.26	H5N3|EPI1997246|A/duck/Bangladesh/17D1839/2022|, input date:
#        	2022.0808219178082, apparent date: 2015.31
#
# 1116.26	H5N3|EPI1997270|A/duck/Bangladesh/18D1811/2022|, input date:
#        	2022.0260273972603, apparent date: 2015.32
#
# 1116.26	H5N3|EPI2197841|A/Mallard/Netherlands/16/2022|, input date:
#        	2022.7219178082191, apparent date: 2015.31
#
# 1116.26	H5N3|EPI1638356|A/Common_Teal/Amur_region/11b/2019|, input date:
#        	2019.6671232876713, apparent date: 2013.55
#
# 1116.26	H5N3|MW404534|A/Mallard-
#        	Anas_platyrhynchos-/South_Korea/KNU2019-51/2019|**gb, input date:
#        	2019.7767123287672, apparent date: 2013.85
#
# 1116.26	H5N3|MW492927|A/mallard/South_Korea/JB21-58/2019|**gb, input date:
#        	2019.7438356164384, apparent date: 2013.44
#
# 1116.26	H5N3|MW493131|A/mallard/South_Korea/JB22-3/2019|**gb, input date:
#        	2019.7438356164384, apparent date: 2013.44
#
# 1116.26	H5N3|EPI1657123|A/Spot-billed_Duck/Russia_Primorje/262/2019|, input
#        	date: 2019.804109589041, apparent date: 2014.06
#
# 1116.26	H5N2|MW404491|A/White-fronted_goose-
#        	Anser_albifrons-/South_Korea/KNU2019-66/2019|**gb, input date:
#        	2019.8424657534247, apparent date: 2013.85
#
# 1116.26	H5N0|EPI1995354|A/duck/Bangladesh/18D1784/2021-|, input date:
#        	2021.941095890411, apparent date: 2015.08
#
# 1116.26	H5N3|EPI1997134|A/duck/Bangladesh/17D1815/2021|, input date:
#        	2021.927397260274, apparent date: 2015.14
#
# 1116.26	H5N3|EPI1958121|A/common_teal/Khabarovsk/84-10V/2021|, input date:
#        	2021.7849315068493, apparent date: 2014.57
#
# 1116.26	H5N3|OM319464|A/mallard/Hokkaido/0110J076C/2021|**gb, input date:
#        	2021.8260273972603, apparent date: 2015.08
#
# 1116.26	H5N1|FJ390061|A/plateau_pika/Qinghai/04/2007|**gb, input date:
#        	2007.2972602739726, apparent date: 1997.82
#
# 1116.26	H5N1|FJ602828|A/bar-headed_goose/Qinghai/13/2008|**gb, input date:
#        	2008.6051912568305, apparent date: 1998.53
#
# 1116.26	H5N1|FJ602824|A/common_cormorant/Qinghai/9/2008|**gb, input date:
#        	2008.5396174863388, apparent date: 1998.53
#
# 1116.26	H5N1|FJ602823|A/common_cormorant/Qinghai/8/2008|**gb, input date:
#        	2008.5396174863388, apparent date: 1998.53
#
# 1116.26	H5N1|FJ602819|A/bar-headed_goose/Qinghai/4/2008|**gb, input date:
#        	2008.4822404371585, apparent date: 1998.63
#
# 1116.26	H5N1|FJ602868|A/bar-headed_goose_/Qinghai/14/2008|**gb, input date:
#        	2008.457650273224, apparent date: 1998.63
#
# 1116.26	H5N1|FJ602822|A/bar-headed_goose/Qinghai/7/2008|**gb, input date:
#        	2008.5314207650274, apparent date: 1998.63
#
# 1116.26	H5N1|FJ602826|A/bar-headed_goose/Qinghai/11/2008|**gb, input date:
#        	2008.6024590163934, apparent date: 1998.63
#
# 1116.26	H5N1|FJ602827|A/common_cormorant/Qinghai/12/2008|**gb, input date:
#        	2008.6434426229507, apparent date: 1998.63
#
# 1116.26	H5N1|FJ602816|A/bar-headed_goose/Qinghai/1/2008|**gb, input date:
#        	2008.3948087431695, apparent date: 1998.63
#
# 1116.26	H5N1|FJ602817|A/bar-headed_goose/Qinghai/2/2008|**gb, input date:
#        	2008.3948087431695, apparent date: 1998.83
#
# 1116.26	H5N1|KX364460|A/swine/Shandong/SD1/2014|**gb, input date:
#        	2014.7849315068493, apparent date: 2001.84
#
# 1116.26	H5N1|KX364468|A/swine/Shandong/SD2/2014|**gb, input date:
#        	2014.8397260273973, apparent date: 2004.11
#
# Inferred sequence evolution model (saved as /Users/threecats/Data/FluSeq/trees/h5_all/tree/sequence_evolution_model.txt):
# Substitution rate (mu): 1.0
#
# Equilibrium frequencies (pi_i):
#   A: 0.3366
#   C: 0.1701
#   G: 0.1973
#   T: 0.2854
#   -: 0.0106
#
# Symmetrized rates from j->i (W_ij):
# 	A	C	G	T	-
#   A	0	0.6061	3.2757	0.2788	0.224
#   C	0.6061	0	0.1527	3.8733	0.0823
#   G	3.2757	0.1527	0	0.3872	0.1485
#   T	0.2788	3.8733	0.3872	0	0.067
#   -	0.224	0.0823	0.1485	0.067	0
#
# Actual rates from j->i (Q_ij):
# 	A	C	G	T	-
#   A	0	0.204	1.1027	0.0938	0.0754
#   C	0.1031	0	0.026	0.6587	0.014
#   G	0.6463	0.0301	0	0.0764	0.0293
#   T	0.0796	1.1055	0.1105	0	0.0191
#   -	0.0024	0.0009	0.0016	0.0007	0
#
#
# Inferred sequence evolution model (saved as /Users/threecats/Data/FluSeq/trees/h5_all/tree/molecular_clock.txt):
# Root-Tip-Regression:
#  --rate:	6.106e-03
#  --r^2:  	0.88
#
# /Users/threecats/miniconda3/lib/python3.9/site-packages/Bio/Phylo/_utils.py:504: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
# --- saved tree as
# 	 /Users/threecats/Data/FluSeq/trees/h5_all/tree/timetree.pdf
#
# --- root-to-tip plot saved to
# 	/Users/threecats/Data/FluSeq/trees/h5_all/tree/root_to_tip_regression.pdf
#
# --- alignment including ancestral nodes saved as
# 	 /Users/threecats/Data/FluSeq/trees/h5_all/tree/ancestral_sequences.fasta
#
# --- saved divergence times in
# 	 /Users/threecats/Data/FluSeq/trees/h5_all/tree/dates.tsv
#
# --- tree saved in nexus format as
# 	 /Users/threecats/Data/FluSeq/trees/h5_all/tree/timetree.nexus
#
# --- divergence tree saved in nexus format as
# 	 /Users/threecats/Data/FluSeq/trees/h5_all/tree/divergence_tree.nexus
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# /var/folders/hg/_k8spj153kv_nlmkjcb474gh0000gn/T/ipykernel_93459/858111242.py in <module>
#      12             for line in fin:
#      13                 if line.startswith(' Tree tree1='):
# ---> 14                     fin.write(line.split('tree1=')[1])
#
# UnsupportedOperation: not writable

# %% [markdown]
# ## Annotations
# Making annotation files

# %%
# define legend categories and colors
colordict_country = {'North_America':'#ff8282',
                'South_America':'#ffb882',
                'Europe':'#82a1ff',
                'Africa':'#fff082',
                'Asia':'#84ff82',
                'Oceania':'#ff82fb',
                'Antarctica':'#e8ffff'
                }

colordict_species = {'terrestrial poultry':'#EE7733',
            'anseriformes+charadriiformes':'#33BBEE',
            'other':'#228833',
            'not determined':'#BBBBBB',
            'human':'#831491',
            'mammal':'#d881e3'
            }

# reread in the species file just in case
with open(species_list, 'r') as f:
    species_dict={line.strip().split('\t')[1]:line.split('\t')[0] for line in f}

# reread in mdata just in case including override
# read in metadata
mdata={}
with open(f'{output_dir}/metadata/mdata.tsv', 'r') as f:
    f.readline() # skip header
    for line in f:
        l=line.strip().split('\t')
        mdata[l[0]]=l[1:]
# read in overrides
with open(f'{output_dir}/metadata/override.tsv', 'r') as f:
    f.readline() # skip header
    for line in f:
        l=line.strip().split('\t')
        mdata[l[0]]=l[1:]

# go through mdata and put into annotation files
with (open(f'{output_dir}/annotations/tree_annotation_strip_geo.txt','w') as f_geo, 
        open(f'{output_dir}/annotations/tree_annotation_strip_species.txt','w') as f_species):
    
    # write headers and legends for annotation files
    f_geo.write('DATASET_COLORSTRIP\nSEPARATOR COMMA\nDATASET_LABEL,geo\nCOLOR,#fdbf6f\nCOLOR_BRANCHES,0\nLEGEND_TITLE,continent\n'+
                f'LEGEND_SHAPES,{",".join(["1" for k in colordict_country.keys()])}\nLEGEND_COLORS,{",".join([colordict_country[k] for k in sorted(colordict_country.keys())])}\nLEGEND_LABELS,{",".join([k for k in sorted(colordict_country.keys())])}\n'+
                'MARGIN,5\nSHOW_STRIP_LABELS,0\nDATA\n')
    f_species.write('DATASET_COLORSTRIP\nSEPARATOR COMMA\nDATASET_LABEL,species\nCOLOR,#fdbf6f\nCOLOR_BRANCHES,0\nLEGEND_TITLE,species category\n'+
                    f'LEGEND_SHAPES,{",".join(["1" for k in colordict_species.keys()])}\nLEGEND_COLORS,{",".join([colordict_species[k] for k in sorted(colordict_species.keys())])}\nLEGEND_LABELS,{",".join([k for k in sorted(colordict_species.keys())])}\n'+
                    'MARGIN,5\nSHOW_STRIP_LABELS,0\nDATA\n')
    
    # write annotation data
    for record in SeqIO.parse(f'{output_dir}/data/{name}.fasta', 'fasta'):
        
        if mdata[record.id][2] != 'unknown':
            f_species.write(f"{record.id},{colordict_species[mdata[record.id][2]]},{mdata[record.id][2]}\n")
        
        if mdata[record.id][3] !='unknown':
            f_geo.write(f"{record.id},{colordict_country[mdata[record.id][3]]},{mdata[record.id][3]}\n")

# %% [markdown]
# # TODO:
